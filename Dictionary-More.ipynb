# %% [markdown]
# ![notebook%20heading-2021.png](attachment:notebook%20heading-2021.png)

# %% [markdown]
# # Dictionary-Operations

# %%
rollnos=[1001,1003,1005,1006,1007,1008]
names=['Avika','Jatin','Anushka','Himanshu','Devinder','Anushka']

# %%
names[rollnos.index(1006)]
# Out:
# 'Himanshu'

# %%
listofstudents=[(1001,'Avika'),(1003,'Jatin'),(1005,'Jatin')]

# %%
for i in listofstudents:
    if i[0]==1003:
          print(i[1])
# Out:
# Jatin

# %%
rollnos[1]
# Out:
# 1003

# %%
zip(names,rollnos)

# %%
dict(zip(names,rollnos))
# Out:
# {'Anushka': 1008,
#  'Avika': 1001,
#  'Devinder': 1007,
#  'Himanshu': 1006,
#  'Jatin': 1003}

# %%
dict(zip(rollnos,names))
# Out:
# {1001: 'Avika',
#  1003: 'Jatin',
#  1005: 'Anushka',
#  1006: 'Himanshu',
#  1007: 'Devinder',
#  1008: 'Anushka'}

# %%
listofstudents=[(1001,'Avika'),(1003,'Jatin'),(1005,'Jatin')]

# %%
mydict=dict(listofstudents)

# %%
mydict
# Out:
# {1001: 'Avika', 1003: 'Jatin', 1005: 'Jatin'}

# %%
employeedict1={
    'empcode':'E001',
    'name':"Sukhmeet",
    'designation':'Manager',
    'salary':50000
}
employeedict2={
    'empcode':'E002',
    'name':"Sumit",
    'designation':'Dy Manager',
    'salary':150000,
    'name':'Dev Monga'
}

# %%
print(employeedict1)
# Out:
# {'empcode': 'E001', 'name': 'Sukhmeet', 'designation': 'Manager', 'salary': 50000}

# %%
listofemployees=[employeedict1,employeedict2]

# %%
listofemployees
# Out:
# [{'designation': 'Manager',
#   'empcode': 'E001',
#   'name': 'Sukhmeet',
#   'salary': 50000},
#  {'designation': 'Dy Manager',
#   'empcode': 'E002',
#   'name': 'Dev Monga',
#   'salary': 150000}]

# %%
employeedict1['designation']
# Out:
# 'Manager'

# %%
# Mapping of one key with Multiple Values

# %%
employeedict1={
    'empcode':'E001',
    'name':"Sukhmeet",
    'designation':'Manager',
    'salary':50000,
    'Department':'R&D',
    'Emails':['sukhmeet@gmail.com','sukhmeet@workplace.com']
}

# %%
employeedict1['Emails'].append('sukhmeit@rediff.com')

# %%
employeedict1['emails']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-106-44e1ab2474bc> in <module>()
# ----> 1 employeedict1['emails']
#
# KeyError: 'emails'

# %%
employeedict1.get('Emails',"No Email Found")
# Out:
# ['sukhmeet@gmail.com', 'sukhmeet@workplace.com', 'sukhmeit@rediff.com']

# %%
#Employee Database

# %%
empdata={
    'E001':employeedict1,
    'E002':employeedict2
}

# %%
empdata
# Out:
# {'E001': {'designation': 'Manager',
#   'empcode': 'E001',
#   'name': 'Sukhmeet',
#   'salary': 50000},
#  'E002': {'designation': 'Dy Manager',
#   'empcode': 'E002',
#   'name': 'Dev Monga',
#   'salary': 150000}}

# %%
empdata['E003']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-2f98ed6b8e90> in <module>()
# ----> 1 empdata['E003']
#
# KeyError: 'E003'

# %%
empdata.get('E001')
# Out:
# {'designation': 'Manager',
#  'empcode': 'E001',
#  'name': 'Sukhmeet',
#  'salary': 50000}

# %%
# Advance Operations
# API - Application Program Interface

# %%
info={"post code": "110001", "country": "India", "country abbreviation": "IN", "places": [{"place name": "Janpath", "longitude": "77.2167", "state": "New Delhi", "state abbreviation": "DL", "latitude": "28.6333"}, {"place name": "Rail Bhawan", "longitude": "77.2167", "state": "New Delhi", "state abbreviation": "DL", "latitude": "28.6333"}, {"place name": "Connaught Place", "longitude": "77.2167", "state": "New Delhi", "state abbreviation": "DL", "latitude": "28.6333"}, {"place name": "Sansadiya Soudha", "longitude": "77.2167", "state": "New Delhi", "state abbreviation": "DL", "latitude": "28.6333"}, {"place name": "Sectt North", "longitude": "77.2167", "state": "New Delhi", "state abbreviation": "DL", "latitude": "28.6333"}, {"place name": "Constitution House", "longitude": "77.2167", "state": "New Delhi", "state abbreviation": "DL", "latitude": "28.6333"}, {"place name": "Eastern Court", "longitude": "77.2167", "state": "New Delhi", "state abbreviation": "DL", "latitude": "28.6333"}, {"place name": "Supreme Court", "longitude": "77.2167", "state": "New Delhi", "state abbreviation": "DL", "latitude": "28.6333"}, {"place name": "Parliament House", "longitude": "77.2167", "state": "New Delhi", "state abbreviation": "DL", "latitude": "28.6333"}, {"place name": "Parliament Street H O", "longitude": "77.2167", "state": "New Delhi", "state abbreviation": "DL", "latitude": "28.6333"}, {"place name": "Laxminarain Mandir", "longitude": "77.2167", "state": "New Delhi", "state abbreviation": "DL", "latitude": "28.6333"}, {"place name": "New Delhi G P O", "longitude": "77.2167", "state": "New Delhi", "state abbreviation": "DL", "latitude": "28.6333"}, {"place name": "Krishi Bhawan", "longitude": "77.2167", "state": "New Delhi", "state abbreviation": "DL", "latitude": "28.6333"}, {"place name": "Lady Harding Medical College", "longitude": "77.2167", "state": "New Delhi", "state abbreviation": "DL", "latitude": "28.6333"}, {"place name": "Election Commission", "longitude": "77.2167", "state": "New Delhi", "state abbreviation": "DL", "latitude": "28.6333"}, {"place name": "North Avenue", "longitude": "77.2167", "state": "New Delhi", "state abbreviation": "DL", "latitude": "28.6333"}, {"place name": "Pragati Maidan", "longitude": "77.2167", "state": "New Delhi", "state abbreviation": "DL", "latitude": "28.6333"}, {"place name": "Patiala House", "longitude": "77.2167", "state": "New Delhi", "state abbreviation": "DL", "latitude": "28.6333"}, {"place name": "Shastri Bhawan", "longitude": "77.2167", "state": "New Delhi", "state abbreviation": "DL", "latitude": "28.6333"}]}

# %%
citykeys=list(info.keys())

# %%
citykeys
# Out:
# ['post code', 'country', 'country abbreviation', 'places']

# %%
info.get('country')
# Out:
# 'India'

# %%
info.get('post code')
# Out:
# '110001'

# %%
places=info.get('places')

# %%
len(places)
# Out:
# 19

# %%
places[0]
# Out:
# {'latitude': '28.6333',
#  'longitude': '77.2167',
#  'place name': 'Janpath',
#  'state': 'New Delhi',
#  'state abbreviation': 'DL'}

# %%
for i in range(len(places)):
    print(places[i].get('place name'))
# Out:
# Janpath
# Rail Bhawan
# Connaught Place
# Sansadiya Soudha
# Sectt North
# Constitution House
# Eastern Court
# Supreme Court
# Parliament House
# Parliament Street H O
# Laxminarain Mandir
# New Delhi G P O
# Krishi Bhawan
# Lady Harding Medical College
# Election Commission
# North Avenue
# Pragati Maidan
# Patiala House
# Shastri Bhawan

# %%
len(info)
# Out:
# 4

# %%
info['places'][0]['place name']
# Out:
# 'Janpath'

# %%
for i in range(len(info['places'])):
    print(info['places'][i]['place name'])
# Out:
# Janpath
# Rail Bhawan
# Connaught Place
# Sansadiya Soudha
# Sectt North
# Constitution House
# Eastern Court
# Supreme Court
# Parliament House
# Parliament Street H O
# Laxminarain Mandir
# New Delhi G P O
# Krishi Bhawan
# Lady Harding Medical College
# Election Commission
# North Avenue
# Pragati Maidan
# Patiala House
# Shastri Bhawan

# %%
# https://api.zippopotam.us/in/110001

# %%
unilist=[{"alpha_two_code": "IN", "web_pages": ["http://www.davietjal.org/"], "name": "DAV Institute of Engineering & Technology", "country": "India", "domains": ["davietjal.org"], "state-province": "Punjab"}, {"alpha_two_code": "IN", "web_pages": ["http://www.lpu.in/"], "name": "Lovely Professional University", "country": "India", "domains": ["lpu.in"], "state-province": "Punjab"}, {"alpha_two_code": "IN", "web_pages": ["https://somaiya.edu/"], "name": "Somaiya Vidyavihar", "country": "India", "domains": ["somaiya.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ncuindia.edu/"], "name": "NorthCap University", "country": "India", "domains": ["ncuindia.edu"], "state-province": "Haryana"}, {"alpha_two_code": "IN", "web_pages": ["http://www.ddu.ac.in/"], "name": "Dharamsinh Desai University", "country": "India", "domains": ["ddu.ac.in"], "state-province": "Gujarat"}, {"alpha_two_code": "IN", "web_pages": ["http://ntruhs.ap.nic.in/"], "name": "University of Health Sciences Andhra Pradesh", "country": "India", "domains": ["ntruhs.ap.nic.in"], "state-province": "Andhra Pradesh"}, {"alpha_two_code": "IN", "web_pages": ["http://www.aaidu.org/"], "name": "Allahabad Agricultural Institute, Deemed University", "country": "India", "domains": ["aaidu.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.aau.ac.in/"], "name": "Assam Agricultural University", "country": "India", "domains": ["aau.ac.in"], "state-province": "Assam"}, {"alpha_two_code": "IN", "web_pages": ["http://www.ahduni.edu.in/"], "name": "Ahmedabad University", "country": "India", "domains": ["ahduni.edu.in"], "state-province": "Gujarat"}, {"alpha_two_code": "IN", "web_pages": ["http://www.aiims.ac.in/"], "name": "All India Institute of Medical Sciences", "country": "India", "domains": ["aiims.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.aisectuniversity.ac.in/"], "name": "AISECT University", "country": "India", "domains": ["aisectuniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.alagappauniversity.ac.in/"], "name": "Alagappa University", "country": "India", "domains": ["alagappauniversity.ac.in"], "state-province": "Tamil Nadu"}, {"alpha_two_code": "IN", "web_pages": ["http://www.alldunivpio.org/"], "name": "Allahabad University", "country": "India", "domains": ["alldunivpio.org"], "state-province": "Uttar Pradesh"}, {"alpha_two_code": "IN", "web_pages": ["http://www.altmeduniversity.com/"], "name": "Open International University for Alternative Medicines", "country": "India", "domains": ["altmeduniversity.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.altmedworld.net/"], "name": "Indian Board of Alternative Medicine", "country": "India", "domains": ["altmedworld.net"], "state-province": "West Bengal"}, {"alpha_two_code": "IN", "web_pages": ["http://www.amity.edu/"], "name": "Amity University", "country": "India", "domains": ["amity.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.amrita.edu/"], "name": "Amrita Vishwa Vidyapeetham (Deemed University)", "country": "India", "domains": ["amrita.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.amtuni.com/"], "name": "Amravati University", "country": "India", "domains": ["amtuni.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.amu.ac.in/"], "name": "Aligarh Muslim University", "country": "India", "domains": ["amu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.andhrauniversity.info/"], "name": "Andhra University", "country": "India", "domains": ["andhrauniversity.info"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.angrau.net/"], "name": "Acharya Ranga Agricultural University", "country": "India", "domains": ["angrau.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.annamalaiuniversity.ac.in/"], "name": "Annamalai University", "country": "India", "domains": ["annamalaiuniversity.ac.in"], "state-province": "Tamil Nadu"}, {"alpha_two_code": "IN", "web_pages": ["http://www.annauniv.edu.in/"], "name": "Anna University of Technology, Tirunelveli", "country": "India", "domains": ["annauniv.edu.in"], "state-province": "Tamil Nadu"}, {"alpha_two_code": "IN", "web_pages": ["http://www.annauniv.edu/"], "name": "Anna University", "country": "India", "domains": ["annauniv.edu"], "state-province": "Tamil Nadu"}, {"alpha_two_code": "IN", "web_pages": ["http://www.apsurewa.nic.in/"], "name": "Awadhesh Pratap Singh University", "country": "India", "domains": ["apsurewa.nic.in"], "state-province": "Madhya Pradesh"}, {"alpha_two_code": "IN", "web_pages": ["http://www.aryainstitutejpr.com/"], "name": "ARYA Institute of Engineering & Technology", "country": "India", "domains": ["aryainstitutejpr.com"], "state-province": "Rajasthan"}, {"alpha_two_code": "IN", "web_pages": ["http://www.assamuniversity.nic.in/"], "name": "Assam University", "country": "India", "domains": ["assamuniversity.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ayurveduniversity.com/"], "name": "Gujarat Ayurved University", "country": "India", "domains": ["ayurveduniversity.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bamu.net/"], "name": "Dr. Babasaheb Ambedkar Marathwada Universtiy", "country": "India", "domains": ["bamu.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bamu.nic.in/"], "name": "Berhampur University", "country": "India", "domains": ["bamu.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.banasthali.org/"], "name": "Banasthali University", "country": "India", "domains": ["banasthali.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bankurauniv.com/"], "name": "Bankura University", "country": "India", "domains": ["bankurauniv.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bau.nic.in/"], "name": "Birsa Agricultural University", "country": "India", "domains": ["bau.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bbauindia.org/"], "name": "Babasaheb Bhimrao Ambedkar University", "country": "India", "domains": ["bbauindia.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bckv.edu.in/"], "name": "Bidhan Chandra Agricultural University", "country": "India", "domains": ["bckv.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bdu.ernet.in/"], "name": "Bharathidasan University", "country": "India", "domains": ["bdu.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.becs.ac.in/"], "name": "Bengal Engineering College", "country": "India", "domains": ["becs.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://bengaluruuniversity.com/"], "name": "Bangalore University", "country": "India", "domains": ["bengaluruuniversity.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bhagwantuniversity.com/"], "name": "Bhagwant University", "country": "India", "domains": ["bhagwantuniversity.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bharathi.ernet.in/"], "name": "Bharathiar University", "country": "India", "domains": ["bharathi.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bharathuniv.com/"], "name": "Bharath Institue Of Higher Education & Research", "country": "India", "domains": ["bharathuniv.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bharatividyapeeth.edu/"], "name": "Bharati Vidyapeeth University", "country": "India", "domains": ["bharatividyapeeth.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bhavuni.edu/"], "name": "Bhavnagar University", "country": "India", "domains": ["bhavuni.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bhu.ac.in/"], "name": "Banaras Hindu University", "country": "India", "domains": ["bhu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://bhub.ori.nic.in/ouat/"], "name": "Orissa University of Agriculture and Technology", "country": "India", "domains": ["bhub.ori.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://bitmesraranchi.org/"], "name": "Birla Institute of Technology, Ranchi", "country": "India", "domains": ["bitmesraranchi.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bits-pilani.ac.in/"], "name": "Birla Institute of Technology and Science", "country": "India", "domains": ["bits-pilani.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bnmu.in/"], "name": "Bhupendra Narayan Mandal University", "country": "India", "domains": ["bnmu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bput.org/"], "name": "Biju Pattnaik University of Technology", "country": "India", "domains": ["bput.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.brabu.net/"], "name": "B. R. Ambedkar Bihar University", "country": "India", "domains": ["brabu.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.braou.ac.in/"], "name": "Dr. B.R. Ambedkar Open University", "country": "India", "domains": ["braou.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitj.ac.in/"], "name": "Dr. B. R. Ambedkar National Institute of Technology Jalandhar", "country": "India", "domains": ["nitj.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.brauagra.com/"], "name": "Dr. Bhim Rao Abdekar University", "country": "India", "domains": ["brauagra.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bsauniv.ac.in/"], "name": "B. S. Abdur Rahman University", "country": "India", "domains": ["bsauniv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bubhopal.nic.in/"], "name": "Barkatullah University", "country": "India", "domains": ["bubhopal.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bundelkhanduniversity.org/"], "name": "Bundelkhand University", "country": "India", "domains": ["bundelkhanduniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.burdwanuniversity.ac.in/"], "name": "University of Burdwan", "country": "India", "domains": ["burdwanuniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.caluniv.ac.in/"], "name": "University of Calcutta", "country": "India", "domains": ["caluniv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.cau.org.in/"], "name": "Central Agricultural University", "country": "India", "domains": ["cau.org.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ccsuniversity.ac.in/"], "name": "Chaudhary Charan Singh University", "country": "India", "domains": ["ccsuniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ccsuniversity.org/"], "name": "Ch. Charan Singh University", "country": "India", "domains": ["ccsuniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.cesbm.ac.in/"], "name": "Center for Entrepreneurship and Small Business Management", "country": "India", "domains": ["cesbm.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.christuniversity.in/"], "name": "Christ University", "country": "India", "domains": ["christuniversity.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ciefl.org/"], "name": "Central Institute of English and Foreign Languages", "country": "India", "domains": ["ciefl.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.cife.edu.in/"], "name": "Central Institute of Fisheries Education", "country": "India", "domains": ["cife.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.cihts.ac.in/"], "name": "Central Institute of Higher Tibetan Studies", "country": "India", "domains": ["cihts.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.cmjuniversity.edu.in/"], "name": "CMJ University", "country": "India", "domains": ["cmjuniversity.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.csauk.ac.in/"], "name": "Chandra Shekhar Azad University of Agriculture and Technology", "country": "India", "domains": ["csauk.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.cusat.ac.in/"], "name": "Cochin University of Science and Technology", "country": "India", "domains": ["cusat.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.cvru.ac.in/"], "name": "Dr. C.V. Raman University", "country": "India", "domains": ["cvru.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.da-iict.org/"], "name": "Dhirubhai Ambani Institute of Information and Communication Technology", "country": "India", "domains": ["da-iict.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.darulhuda.com/"], "name": "Darul Huda Islamic University", "country": "India", "domains": ["darulhuda.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.davuniversity.org/"], "name": "Dav University", "country": "India", "domains": ["davuniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.davv.ac.in/"], "name": "Devi Ahilya University of Indore", "country": "India", "domains": ["davv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.dbatechuni.org/"], "name": "Dr. Babasaheb Ambedkar Technological University", "country": "India", "domains": ["dbatechuni.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.dbskkv.org/"], "name": "Konkan Agricultural University", "country": "India", "domains": ["dbskkv.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://dbs.tn.nic.in/tnau/"], "name": "Tamil Nadu Agricultural University", "country": "India", "domains": ["dbs.tn.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.dceonline.net/"], "name": "Delhi College of Engineering (DCE)", "country": "India", "domains": ["dceonline.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ddugu.edu.in/"], "name": "Deen Dayal Upadhyay Gorakhpur University", "country": "India", "domains": ["ddugu.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.deccancollegepune.ac.in/"], "name": "Deccan College Postgraduate and Research Institute", "country": "India", "domains": ["deccancollegepune.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.dei.ac.in/"], "name": "Dayalbagh Educational Institute", "country": "India", "domains": ["dei.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.dibru.ernet.in/"], "name": "Dibrugarh University", "country": "India", "domains": ["dibru.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.dravidianuniversity.ac.in/"], "name": "Dravidian University", "country": "India", "domains": ["dravidianuniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.du.ac.in/"], "name": "University of Delhi", "country": "India", "domains": ["du.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.dypatiluniversity.org/"], "name": "Dr. D.Y. Patil University", "country": "India", "domains": ["dypatiluniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.eiilmuniversity.ac.in/"], "name": "Eiilm University", "country": "India", "domains": ["eiilmuniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.fatimacollege.net/"], "name": "Fatima mata national college kollam kerala", "country": "India", "domains": ["fatimacollege.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://fri.icfre.gov.in/"], "name": "Forest Research Institute Dehradun", "country": "India", "domains": ["fri.icfre.gov.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.gbpuat.ac.in/"], "name": "Govind Ballabh Pant University of Agriculture and Technology", "country": "India", "domains": ["gbpuat.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ggu.ac.in/"], "name": "Guru Ghasidas University", "country": "India", "domains": ["ggu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.gipe.ernet.in/"], "name": "Gokhale Institute of Politics and Economics", "country": "India", "domains": ["gipe.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.gitam.edu/"], "name": "Gandhi Institute of Technology and Managment", "country": "India", "domains": ["gitam.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.gju.ernet.in/"], "name": "Guru Jambeshwar University", "country": "India", "domains": ["gju.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.gkvharidwar.org/"], "name": "Gurukula Kangri University", "country": "India", "domains": ["gkvharidwar.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.gnduonline.org/"], "name": "Guru Nanak Dev University", "country": "India", "domains": ["gnduonline.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.government.ind.in/"], "name": "Global Open University , Nagaland", "country": "India", "domains": ["government.ind.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.gtu.ac.in/"], "name": "Gujarat Technological University Ahmedabad", "country": "India", "domains": ["gtu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.gujaratuniversity.org.in/"], "name": "Gujarat University Ahmedabad", "country": "India", "domains": ["gujaratuniversity.org.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.gulbargauniversity.kar.nic.in/"], "name": "Gulbarga University", "country": "India", "domains": ["gulbargauniversity.kar.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.gu.nic.in/"], "name": "Gauhati University", "country": "India", "domains": ["gu.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.gurukuluniversity.org/"], "name": "Gurukul University", "country": "India", "domains": ["gurukuluniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://hau.ernet.in/"], "name": "CCS Haryana Agricultural University", "country": "India", "domains": ["hau.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.hau.ernet.in/"], "name": "Chaudhary Charan Singh Haryana Agricultural University", "country": "India", "domains": ["hau.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://hillagric.ernet.in/"], "name": "Himachal Pradesh Agricultural University", "country": "India", "domains": ["hillagric.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.hnbgu.ac.in/"], "name": "Hemwati Nandan Bahuguna Garhwal University", "country": "India", "domains": ["hnbgu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.hnluraipur.com/"], "name": "Hidayatullah National Law University, Raipur", "country": "India", "domains": ["hnluraipur.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.hostindia.com/srmc/"], "name": "Sri Ramachardra Medical College and Research Institute", "country": "India", "domains": ["hostindia.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://hpuniv.nic.in/"], "name": "Himachal Pradesh University", "country": "India", "domains": ["hpuniv.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iari.ernet.in/"], "name": "Indian Agricultural Research Institute", "country": "India", "domains": ["iari.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iaseduniv.org/"], "name": "IASE (Institute of Advanced Studies) Deemed University", "country": "India", "domains": ["iaseduniv.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.icfai.org/"], "name": "ICFAI University", "country": "India", "domains": ["icfai.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.iudehradun.edu.in/"], "name": "ICFAI University, Dehradun", "country": "India", "domains": ["iudehradun.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.iutripura.edu.in/"], "name": "ICFAI University, Tripura", "country": "India", "domains": ["iutripura.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.iusikkim.edu.in/"], "name": "ICFAI University, Sikkim", "country": "India", "domains": ["iusikkim.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.iumizoram.edu.in/"], "name": "ICFAI University, Mizoram", "country": "India", "domains": ["iumizoram.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.iumeghalaya.edu.in/"], "name": "ICFAI University, Meghalaya", "country": "India", "domains": ["iumeghalaya.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.iujharkhand.edu.in/"], "name": "ICFAI University, Jharkhand", "country": "India", "domains": ["iujharkhand.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.iunagaland.edu.in/"], "name": "ICFAI University, Nagaland", "country": "India", "domains": ["iunagaland.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.iujaipur.edu.in/"], "name": "ICFAI University, Jaipur", "country": "India", "domains": ["iujaipur.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.iuraipur.edu.in/"], "name": "ICFAI University, Raipur", "country": "India", "domains": ["iuraipur.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.iuhimachal.edu.in/"], "name": "ICFAI University, Himachal Pradesh", "country": "India", "domains": ["iuhimachal.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.ifheindia.org/"], "name": "ICFAI University, Hyderabad", "country": "India", "domains": ["ifheindia.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.igau.edu.in/"], "name": "Indira Gandhi Agricultural University", "country": "India", "domains": ["igau.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.igidr.ac.in/"], "name": "Indira Gandhi Institute of Development and Research", "country": "India", "domains": ["igidr.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.igims.org/"], "name": "Indira Gandhi Institute of Medical Sciences", "country": "India", "domains": ["igims.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ignou.ac.in/"], "name": "Indira Gandhi National Open University", "country": "India", "domains": ["ignou.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iiita.com/"], "name": "Indian Institute of Information Technology", "country": "India", "domains": ["iiita.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iiitmk.ac.in/"], "name": "Indian Institute of Information Technology and Management - Kerala", "country": "India", "domains": ["iiitmk.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iiitm.ac.in/"], "name": "Indian Institute of Information Technology and Management - Gwalior", "country": "India", "domains": ["iiitm.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iiitd.ac.in/"], "name": "Indraprastha Institute of Information Technology, Delhi", "country": "India", "domains": ["iiitd.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["www.isquareit.ac.in/"], "name": "International Institute of Information Technology, Pune", "country": "India", "domains": ["squareit.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["www.iiit-bh.ac.in/"], "name": "International Institute of Information Technology, Bhubaneswar", "country": "India", "domains": ["iiit-bh.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["www.iiitb.ac.in/"], "name": "International Institute of Information Technology, Bangalore", "country": "India", "domains": ["iiitb.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iimtrichy.ac.in/"], "name": "Indian Institute of Management, Tiruchirappalli", "country": "India", "domains": ["iimtrichy.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iimtrichy.ac.in/"], "name": "Indian Institute of Information Technology, Guwahati", "country": "India", "domains": ["iiitg.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://iiitvadodara.ac.in/"], "name": "Indian Institute of Information Technology, Vadodara", "country": "India", "domains": ["iiitvadodara.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://iiitkota.ac.in/"], "name": "Indian Institute of Information Technology, Kota", "country": "India", "domains": ["iiitkota.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iipsindia.org/"], "name": "International Institute for Population Sciences", "country": "India", "domains": ["iipsindia.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iisc.ernet.in/"], "name": "Indian Institute of Science", "country": "India", "domains": ["iisc.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iitb.ac.in/"], "name": "Indian Institute of Technology, Bombay", "country": "India", "domains": ["iitb.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iitd.ernet.in/"], "name": "Indian Institute of Technology, Delhi", "country": "India", "domains": ["iitd.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://iitgn.ac.in/"], "name": "Indian Institute of Technology, Gandhinagar", "country": "India", "domains": ["iitgn.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iitg.ernet.in/", "http://www.iitg.ac.in/"], "name": "Indian Institute of Technology, Guwahati", "country": "India", "domains": ["iitg.ernet.in", "iitg.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iith.ac.in/"], "name": "Indian Institute of Technology, Hyderabad", "country": "India", "domains": ["iith.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iitk.ac.in/"], "name": "Indian Institute of Technology, Kanpur", "country": "India", "domains": ["iitk.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iitkgp.ernet.in/"], "name": "Indian Institute of Technology, Kharagpur", "country": "India", "domains": ["iitkgp.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iitm.ac.in/"], "name": "Indian Institute of Technology, Madras", "country": "India", "domains": ["iitm.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.mitindia.edu/en/"], "name": "Madras Institute of Technology", "country": "India", "domains": ["mitindia.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iitr.ac.in/"], "name": "Indian Institute of Technology, Roorkee", "country": "India", "domains": ["iitr.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iitp.ac.in/"], "name": "Indian Institute of Technology, Patna", "country": "India", "domains": ["iitp.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iiti.ac.in/"], "name": "Indian Institute of Technology, Indore", "country": "India", "domains": ["iiti.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iitj.ac.in/"], "name": "Indian Institute of Technology, Jodhpur", "country": "India", "domains": ["iitj.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iksvv.com/"], "name": "University of Music and Fine Arts", "country": "India", "domains": ["iksvv.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ilidelhi.org/"], "name": "Indian Law Institue", "country": "India", "domains": ["ilidelhi.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.indusuni.ac.in/"], "name": "Indus University", "country": "India", "domains": ["indusuni.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.integraluniversity.ac.in/"], "name": "Integral University", "country": "India", "domains": ["integraluniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ipu.ac.in/"], "name": "Guru Gobind Singh Indraprastha University", "country": "India", "domains": ["ipu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://isbm.org.in/"], "name": "Indian School of Business Management and Administration", "country": "India", "domains": ["isbm.org.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.isical.ac.in/"], "name": "Indian Statistical Institute", "country": "India", "domains": ["isical.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ismdhanbad.ac.in/"], "name": "Indian School of Mines (ISM)", "country": "India", "domains": ["ismdhanbad.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.itmindia.edu/"], "name": "Institute of Technology and Management", "country": "India", "domains": ["itmindia.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iur.ac.in/"], "name": "Indian University", "country": "India", "domains": ["iur.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ivri.nic.in/"], "name": "Indian Veterinary Research Institute", "country": "India", "domains": ["ivri.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jadavpur.edu/"], "name": "Jadavpur University", "country": "India", "domains": ["jadavpur.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jainuniversity.org/"], "name": "First Global University to teaching Jainism", "country": "India", "domains": ["jainuniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jamiahamdard.edu/"], "name": "Jamia Hamdard University", "country": "India", "domains": ["jamiahamdard.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jammuvarsity.org/"], "name": "University of Jammu", "country": "India", "domains": ["jammuvarsity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jiit.ac.in/"], "name": "Jaypee Institute of Information Technology", "country": "India", "domains": ["jiit.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jiwaji.edu/"], "name": "Jiwaji University", "country": "India", "domains": ["jiwaji.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://jmi.nic.in/"], "name": "Jamia Millia Islamia University", "country": "India", "domains": ["jmi.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jncasr.ac.in/"], "name": "Jawaharlal Nehru Centre for Advanced  Scientific Research", "country": "India", "domains": ["jncasr.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jnkvv.nic.in/"], "name": "Jawaharlal Nehru Agricultural University", "country": "India", "domains": ["jnkvv.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jntu.ac.in/"], "name": "Jawaharlal Nehru Technological University", "country": "India", "domains": ["jntu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jnu.ac.in/"], "name": "Jawaharlal Nehru University", "country": "India", "domains": ["jnu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jnujaipur.ac.in/"], "name": "Jaipur National University", "country": "India", "domains": ["jnujaipur.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jodhpurnationaluniversity.com/"], "name": "Jodhpur National University", "country": "India", "domains": ["jodhpurnationaluniversity.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://jpv.bih.nic.in/"], "name": "Jai Prakash University", "country": "India", "domains": ["jpv.bih.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jrnrvu.org/"], "name": "Rajasthan Vidyapeeth University", "country": "India", "domains": ["jrnrvu.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jvbi.ac.in/"], "name": "Jain Vishva Bharati Institute", "country": "India", "domains": ["jvbi.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kalingauniversity.com/"], "name": "Kalinga University", "country": "India", "domains": ["kalingauniversity.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kanchiuniv.ac.in/"], "name": "Sri Chandrasekharendra Saraswathi Viswa Mahavidyalaya", "country": "India", "domains": ["kanchiuniv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kannadauniversity.org/"], "name": "Kannada University", "country": "India", "domains": ["kannadauniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kannuruniversity.ac.in/"], "name": "Kannur University", "country": "India", "domains": ["kannuruniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kanpuruniversity.org/"], "name": "Chhatrapati Shahu Ji Maharaj University", "country": "India", "domains": ["kanpuruniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kanpuruniversity.org/"], "name": "Kanpur University", "country": "India", "domains": ["kanpuruniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.karnatakastateopenuniversity.in/"], "name": "Karnataka State Open University", "country": "India", "domains": ["karnatakastateopenuniversity.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.karpagamuniv.com/"], "name": "Karpagam University", "country": "India", "domains": ["karpagamuniv.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.karunya.edu/"], "name": "Karunya Institute Of Technology ( Deemed University)", "country": "India", "domains": ["karunya.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://kashmiruniversity.net/"], "name": "University of Kashmir", "country": "India", "domains": ["kashmiruniversity.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kau.edu/"], "name": "Kerala Agricultural University", "country": "India", "domains": ["kau.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.keralauniversity.ac.in/"], "name": "University of Kerala", "country": "India", "domains": ["keralauniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://kimi.kohinoor.ac.in/"], "name": "Kohinoor School of Hospitality Management", "country": "India", "domains": ["kimi.kohinoor.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.klyuniv.ac.in/"], "name": "University of Kalyani", "country": "India", "domains": ["klyuniv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.krishnauniversity.ac.in/"], "name": "Krishna University", "country": "India", "domains": ["krishnauniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ksdsu.edu.in/"], "name": "Kameshwar Singh Darbhanga Sanskrit University", "country": "India", "domains": ["ksdsu.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kslu.ac.in/"], "name": "Karnataka State Law University", "country": "India", "domains": ["kslu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kud.ac.in/"], "name": "Karnatak University", "country": "India", "domains": ["kud.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kufos.ac.in/"], "name": "Kerala University of Fisheries and Ocean Sciences", "country": "India", "domains": ["kufos.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kukinfo.com/"], "name": "Kurukshetra University", "country": "India", "domains": ["kukinfo.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kct.ac.in/"], "name": "Kumaraguru College of Technology", "country": "India", "domains": ["kct.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kumaununiversity.org/"], "name": "Kumaun University", "country": "India", "domains": ["kumaununiversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kuvempu.ac.in/"], "name": "Kuvempu University", "country": "India", "domains": ["kuvempu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kuwarangal.com/"], "name": "Kakatiya University", "country": "India", "domains": ["kuwarangal.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ldceahd.org/"], "name": "L.D.College of Engineering", "country": "India", "domains": ["ldceahd.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.lnipe.edu/"], "name": "Lakshmibai National Institute of Physical Education", "country": "India", "domains": ["lnipe.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://lnmu.bih.nic.in/"], "name": "Lalit Narayan Mithila University", "country": "India", "domains": ["lnmu.bih.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.lucknowuniv.org/"], "name": "University of Lucknow", "country": "India", "domains": ["lucknowuniv.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.macfast.org/"], "name": "Mar Athanasios College for Advanced Studies", "country": "India", "domains": ["macfast.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.magadhuniversity.org/"], "name": "Magadh University", "country": "India", "domains": ["magadhuniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mangaloreuniversity.ac.in/"], "name": "Mangalore University", "country": "India", "domains": ["mangaloreuniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.manipal.edu/"], "name": "Manipal University", "country": "India", "domains": ["manipal.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.manipur.nic.in/maniuniversity.htm"], "name": "Manipur University", "country": "India", "domains": ["manipur.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.manuu.ac.in/"], "name": "Moulana Azad national Urdu University", "country": "India", "domains": ["manuu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mcu.ac.in/"], "name": "Makanlal Chutur Vedi University", "country": "India", "domains": ["mcu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mcu.ac.in/"], "name": "Makhanlal Chaturvedi National University of Journalism and Communication", "country": "India", "domains": ["mcu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mdsuajmer.ac.in/"], "name": "Maharshi Dayanand Sarswati University Ajmer", "country": "India", "domains": ["mdsuajmer.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mdurohtak.com/"], "name": "Maharishi Dayanand University, Rohtak (Haryana )", "country": "India", "domains": ["mdurohtak.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mgkvp.ac.in/"], "name": "Mahatma Gandhi Kashi Vidyapith", "country": "India", "domains": ["mgkvp.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mgsubikaner.ac.in/"], "name": "Maharaja Ganga Singh University, Bikaner", "country": "India", "domains": ["mgsubikaner.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mgu.ac.in/"], "name": "Mahatma Gandhi University, Kerala", "country": "India", "domains": ["mgu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mjpru.ac.in/"], "name": "Mahatma Jyotiba Phule Rohilkhand University Bareilly", "country": "India", "domains": ["mjpru.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mkuhyd.com/"], "name": "Madurai Kamaraj University", "country": "India", "domains": ["mkuhyd.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://mkv2.mah.nic.in/"], "name": "Marathwada Agricultural University", "country": "India", "domains": ["mkv2.mah.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mlsu.ac.in/"], "name": "Mohan Lal Sukhadia University", "country": "India", "domains": ["mlsu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mnnit.ac.in/"], "name": "Motilal Nehru National Institute Of Technology", "country": "India", "domains": ["mnnit.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mpbou.org/"], "name": "Madhya Pradesh Bhoj (Open) University", "country": "India", "domains": ["mpbou.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://mpkv.mah.nic.in/"], "name": "Mahatma Phule Agricultural University", "country": "India", "domains": ["mpkv.mah.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.msubaroda.ac.in/"], "name": "Maharaja Sayajirao University of Baroda", "country": "India", "domains": ["msubaroda.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mu.ac.in/"], "name": "University of Mumbai", "country": "India", "domains": ["mu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nagarjunauniversity.ac.in/"], "name": "Acharya Nagarjuna University", "country": "India", "domains": ["nagarjunauniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nagauniv.org.in/"], "name": "Nagaland University", "country": "India", "domains": ["nagauniv.org.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nagpur-university.com/"], "name": "Nagpur University", "country": "India", "domains": ["nagpur-university.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nalandaopenuniversity.info/"], "name": "Nalanda Open University", "country": "India", "domains": ["nalandaopenuniversity.info"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nationalmuseumindia.org/nmi/index.htm"], "name": "National Museum Institute of History of Art, Conservation and Museology", "country": "India", "domains": ["nationalmuseumindia.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nbu.ac.in/"], "name": "University of North Bengal", "country": "India", "domains": ["nbu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://ndri.nic.in/"], "name": "National Dairy Research Institute", "country": "India", "domains": ["ndri.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nduat.nic.in/"], "name": "Narendra Deva University of Agriculture and Technology", "country": "India", "domains": ["nduat.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nehu.ac.in/"], "name": "North Eastern Hill University", "country": "India", "domains": ["nehu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ngu.ac.in/"], "name": "Hemchandracharay North Gujarat University", "country": "India", "domains": ["ngu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nimhans.kar.nic.in/"], "name": "National Institute of Mental Health and Neuro Sciences", "country": "India", "domains": ["nimhans.kar.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://nims.ap.nic.in/"], "name": "Nizam's Institute of Medical Sciences", "country": "India", "domains": ["nims.ap.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nims.net.in/"], "name": "Institute of Management Studies", "country": "India", "domains": ["nims.net.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nirmauni.ac.in/"], "name": "Nirma University", "country": "India", "domains": ["nirmauni.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitie.edu/"], "name": "National Institute of Industrial Engineering", "country": "India", "domains": ["nitie.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nita.ac.in/"], "name": "National Institute of Technology Agartala", "country": "India", "domains": ["nita.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitandhra.ac.in/"], "name": "National Institute of Technology Andhra Pradesh", "country": "India", "domains": ["nitandhra.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitap.in/"], "name": "National Institute of Technology Arunachal Pradesh", "country": "India", "domains": ["nitap.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitc.ac.in/"], "name": "National Institute of Technology Calicut", "country": "India", "domains": ["nitc.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitdelhi.ac.in/"], "name": "National Institute of Technology Delhi", "country": "India", "domains": ["nitdelhi.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitdgp.ac.in/"], "name": "National Institute of Technology Durgapur", "country": "India", "domains": ["nitdgp.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitgoa.ac.in/"], "name": "National Institute of Technology Goa", "country": "India", "domains": ["nitgoa.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nith.ac.in/"], "name": "National Institute of Technology Hamirpur", "country": "India", "domains": ["nith.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitjsr.ac.in/"], "name": "National Institute of Technology Jamshedpur", "country": "India", "domains": ["nitjsr.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitkkr.net/"], "name": "National Institute of Technology Kurukshetra", "country": "India", "domains": ["nitkkr.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitmanipur.ac.in"], "name": "National Institute of Technology Manipur", "country": "India", "domains": ["nitmanipur.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitm.ac.in"], "name": "National Institute of Technology Meghalaya", "country": "India", "domains": ["nitm.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitmz.ac.in"], "name": "National Institute of Technology Mizoram", "country": "India", "domains": ["nitmz.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitnagaland.ac.in"], "name": "National Institute of Technology Nagaland", "country": "India", "domains": ["nitnagaland.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitp.ac.in"], "name": "National Institute of Technology Patna", "country": "India", "domains": ["nitp.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitpy.ac.in"], "name": "National Institute of Technology Puducherry", "country": "India", "domains": ["nitpy.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitrr.ac.in"], "name": "National Institute of Technology Raipur", "country": "India", "domains": ["nitrr.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitrkl.ac.in/"], "name": "National Institute of Technology Rourkela", "country": "India", "domains": ["nitrkl.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitsikkim.ac.in/"], "name": "National Institute of Technology Sikkim", "country": "India", "domains": ["nitsikkim.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nits.ac.in/"], "name": "National Institute of Technology Silchar", "country": "India", "domains": ["nits.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitsri.net/"], "name": "National Institute of Technology Srinagar", "country": "India", "domains": ["nitsri.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitk.ac.in/"], "name": "National Institute of Technology Surathkal", "country": "India", "domains": ["nitk.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitt.edu/"], "name": "National Institute of Technology Trichy", "country": "India", "domains": ["nitt.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nituk.ac.in/"], "name": "National Institute of Technology Uttarakhand", "country": "India", "domains": ["nituk.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitw.ernet.in/"], "name": "National Institute of Technology Warangal", "country": "India", "domains": ["nitw.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nls.ac.in/"], "name": "National Law School of India University", "country": "India", "domains": ["nls.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nmims.edu/"], "name": "Narsee Monjee Institute of Management Studies", "country": "India", "domains": ["nmims.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nmu.ac.in/"], "name": "North Maharashtra University", "country": "India", "domains": ["nmu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nsit.ac.in/"], "name": "Netaji Subhas Institute of Technology", "country": "India", "domains": ["nsit.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.osmania.ac.in/"], "name": "Osmania University", "country": "India", "domains": ["osmania.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.padmavatiwomen-univ.org/"], "name": "Sri Padmavati Women's University", "country": "India", "domains": ["padmavatiwomen-univ.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.pdpu.ac.in/"], "name": "Pandit Deendayal Petroleum University", "country": "India", "domains": ["pdpu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.pau.edu/"], "name": "Punjab Agricultural University", "country": "India", "domains": ["pau.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.pdkv.ac.in/"], "name": "Dr. Panjabrao Deshmukh Krishi Vidyapeeth", "country": "India", "domains": ["pdkv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.paruluniversity.ac.in/"], "name": "Parul University", "country": "India", "domains": ["paruluniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.pec.ac.in/"], "name": "Punjab Engineering College", "country": "India", "domains": ["pec.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.pes.edu/"], "name": "Pes University", "country": "India", "domains": ["pes.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.pgimer.nic.in/"], "name": "Postgraduate lnstitute of Medical Education and Research", "country": "India", "domains": ["pgimer.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.pondiuni.org/"], "name": "Pondicherry University", "country": "India", "domains": ["pondiuni.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.psgtech.edu/"], "name": "PSG College of Technology", "country": "India", "domains": ["psgtech.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ptetjnvu.org/"], "name": "Jai Narain Vyas University", "country": "India", "domains": ["ptetjnvu.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ptu.ac.in/"], "name": "Punjab Technical University", "country": "India", "domains": ["ptu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.puchd.ac.in/"], "name": "Panjab University", "country": "India", "domains": ["puchd.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.punjabiuniversity.ac.in/"], "name": "Punjabi University Patiala", "country": "India", "domains": ["punjabiuniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://puonline.bih.nic.in/"], "name": "Patna University", "country": "India", "domains": ["puonline.bih.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.pusavarsity.org.in/"], "name": "Rajendra Agricultural University", "country": "India", "domains": ["pusavarsity.org.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.rabindrabharatiuniversity.net/"], "name": "Rabindra Bharati University", "country": "India", "domains": ["rabindrabharatiuniversity.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ranchiuniversity.org.in/"], "name": "Ranchi University", "country": "India", "domains": ["ranchiuniversity.org.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.raubikaner.org/"], "name": "Rajasthan Agricultural University, Bikaner", "country": "India", "domains": ["raubikaner.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.rdunijbpin.org/"], "name": "Rani Durgavati University", "country": "India", "domains": ["rdunijbpin.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.rgtu.net/"], "name": "Rajiv Gandhi Technical University (University of Technology of Madhya Pradesh)", "country": "India", "domains": ["rgtu.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.rgu.ac.in/"], "name": "Rajiv Gandhi University", "country": "India", "domains": ["rgu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.riths.ac.in/"], "name": "Rajitlal Institute of Technology & Health Sciences (RITHS)", "country": "India", "domains": ["riths.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.rmlau.ac.in/"], "name": "Dr. Ram Manohar Lohia Avadh University", "country": "India", "domains": ["rmlau.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.rsuniversity.com/"], "name": "Pandit Ravi Shankar Shukla University", "country": "India", "domains": ["rsuniversity.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.rtu.ac.in/"], "name": "Rajasthan Technical University", "country": "India", "domains": ["rtu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ruraluniversity-chitrakoot.org/"], "name": "Mahatma Gandhi Chitrakut Gramoday University", "country": "India", "domains": ["ruraluniversity-chitrakoot.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.sagaruniversity.nic.in/"], "name": "Dr. Hari Singh Gour University, formerly University of Sagar", "country": "India", "domains": ["sagaruniversity.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.sambalpuruniversitypgc.in/"], "name": "Sambalpur University", "country": "India", "domains": ["sambalpuruniversitypgc.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.sanskrit.nic.in/"], "name": "National Sanskrit University", "country": "India", "domains": ["sanskrit.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.sastra.edu/"], "name": "SASTRA Deemed University", "country": "India", "domains": ["sastra.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.sathyabamauniv.ac.in/"], "name": "Sathyabama University", "country": "India", "domains": ["sathyabamauniv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.saurashtrauniversity.edu/"], "name": "Saurashtra University", "country": "India", "domains": ["saurashtrauniversity.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.sce.ac.in/"], "name": "Shanmugha Arts Science Technology and Research Academy", "country": "India", "domains": ["sce.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://sctimst.ker.nic.in/"], "name": "Sree Chitra Tirunal Institute for Medical Sciences and Technology", "country": "India", "domains": ["sctimst.ker.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.sdau.edu.in/"], "name": "Sardarkrushinagar Dantiwada Agricultural University", "country": "India", "domains": ["sdau.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.sgpgi.ac.in/"], "name": "Sanjay Gandhi Postgraduate lnstitute of Medical Sciences", "country": "India", "domains": ["sgpgi.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.sgu.ernet.in/"], "name": "South Gujarat University", "country": "India", "domains": ["sgu.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.shobhituniversity.ac.in/"], "name": "Shobhit University, Meerut", "country": "India", "domains": ["shobhituniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.shridharuniversity.ac.in/"], "name": "Shridhar University", "country": "India", "domains": ["shridharuniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.simhapuriuniv.ac.in/"], "name": "Vikrama Simhapuri University", "country": "India", "domains": ["simhapuriuniv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.siu.edu.in/"], "name": "Symbiosis International University", "country": "India", "domains": ["siu.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.sjsv.nic.in/"], "name": "Shri Jagannath Sanskrit University", "country": "India", "domains": ["sjsv.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.skmu.edu.in/"], "name": "Sido Kanhu Murmu University", "country": "India", "domains": ["skmu.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.skuastkashmir.ac.in/"], "name": "Sher-E-Kashmir University of Agricultural Sciences and Technology", "country": "India", "domains": ["skuastkashmir.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://skuniv.ap.nic.in/"], "name": "Sri Krishnadevaraya University", "country": "India", "domains": ["skuniv.ap.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.slbsrsv.ac.in/"], "name": "Shri Lal Bahadur Shastri Rashtriya Sanskrit Vidyapeetha", "country": "India", "domains": ["slbsrsv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.smkfomra.net/"], "name": "SMK Fomra Institute of Technology", "country": "India", "domains": ["smkfomra.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.smu.edu.in/"], "name": "Sikkim Manipal University of Health, Medical and Technological Sciences", "country": "India", "domains": ["smu.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.sndt.edu/"], "name": "Shreemati Nathibai Damodar Thackersey Women's University", "country": "India", "domains": ["sndt.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.soauniversity.ac.in/"], "name": "Sikha 'O' Anushandhan University", "country": "India", "domains": ["soauniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.southasianuniversity.org/"], "name": "South Asian University", "country": "India", "domains": ["southasianuniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.spa.ac.in/"], "name": "School of Planning and Architecture", "country": "India", "domains": ["spa.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.spuniv.org/"], "name": "Periyar University", "country": "India", "domains": ["spuniv.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.spuvvn.edu/"], "name": "Sardar Patel University", "country": "India", "domains": ["spuvvn.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.srisathyasai.org.in/pages/instts/HighLearn.htm"], "name": "Sri Sathya Sai Institute of Higher Learning", "country": "India", "domains": ["srisathyasai.org.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.srkdc.org/"], "name": "Sree Rama Krishna Degree College", "country": "India", "domains": ["srkdc.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.srmuniv.ac.in/"], "name": "SRM Institute Of Science & Technology ( Deemed University)", "country": "India", "domains": ["srmuniv.ac.in"], "state-province": "Tamil Nadu"}, {"alpha_two_code": "IN", "web_pages": ["http://www.srtmun.org/"], "name": "Swami Ramanand Teerth Marathwada University", "country": "India", "domains": ["srtmun.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ssgmce.org/"], "name": "Sri Sant Gajanan Maharaj College of Engineering", "country": "India", "domains": ["ssgmce.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ssus.ac.in/"], "name": "Sree Sankaracharya University of Sanskrit", "country": "India", "domains": ["ssus.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://ssvv.up.nic.in/"], "name": "Sampurnanand Sanskrit University", "country": "India", "domains": ["ssvv.up.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://su.digitaluniversity.ac/"], "name": "Solapur University", "country": "India", "domains": ["su.digitaluniversity.ac"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.svbpuctm.org/"], "name": "Sardar Vallabhai Patel University of Agriculture Amd Technology", "country": "India", "domains": ["svbpuctm.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.svnit.ac.in/"], "name": "Sardar Vallabhbhai National Institute of Technology", "country": "India", "domains": ["svnit.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://svimstpt.ap.nic.in/"], "name": "Sri Venkateswara Institute of Medical Sciences", "country": "India", "domains": ["svimstpt.ap.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://svuni.ap.nic.in/"], "name": "Sri Venkateswara University", "country": "India", "domains": ["svuni.ap.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tamiluniversity.ac.in/"], "name": "Tamil University", "country": "India", "domains": ["tamiluniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tanuvas.com/"], "name": "Tamil Nadu Veterinary and Animal Sciences University", "country": "India", "domains": ["tanuvas.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tce.edu/"], "name": "Thiagarajar College of Engineering", "country": "India", "domains": ["tce.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.teluguuniversity.ac.in/"], "name": "Potti Sreeramulu Telugu University", "country": "India", "domains": ["teluguuniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.teluguuniversity.ac.in/"], "name": "Telugu University", "country": "India", "domains": ["teluguuniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tezu.ernet.in/"], "name": "Tezpur University", "country": "India", "domains": ["tezu.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.thenewcollege.org/"], "name": "The New College", "country": "India", "domains": ["thenewcollege.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tiet.ac.in/"], "name": "Thapar Institute of Engineering and Technology", "country": "India", "domains": ["tiet.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tiss.edu/"], "name": "Tata Institute of Social Sciences", "country": "India", "domains": ["tiss.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tmbu.org/"], "name": "Tilka Manjhi Bhagalpur University", "country": "India", "domains": ["tmbu.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tmv.edu.in/"], "name": "Tilak Maharashtra Vidyapeeth", "country": "India", "domains": ["tmv.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tndalu.org/"], "name": "Tamil Nadu Dr. Ambedkar Law University", "country": "India", "domains": ["tndalu.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tnmmu.ac.in/"], "name": "Tamil Nadu Dr. M.G.R. Medical University", "country": "India", "domains": ["tnmmu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tnuniv.ac.in/adu/"], "name": "Avinashilingam Institute for Home Science and Higher Education for Women", "country": "India", "domains": ["tnuniv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tnuniv.ac.in/gri/"], "name": "Gandhigram Rural Institute", "country": "India", "domains": ["tnuniv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tnuniv.ac.in/msu/"], "name": "Manonmaniam Sundaranar University", "country": "India", "domains": ["tnuniv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tnuniv.ac.in/mteresa/"], "name": "Mother Teresa Women's University", "country": "India", "domains": ["tnuniv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.manit.ac.in/"], "name": "Maulana Azad National Institute of Technology Bhopal", "country": "India", "domains": ["manit.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mnit.ac.in/"], "name": "Malaviya National Institute of Technology Jaipur", "country": "India", "domains": ["mnit.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tripurauniv.in/"], "name": "Tripura University", "country": "India", "domains": ["tripurauniv.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tshmc.org/"], "name": "Takhatmal Shrivallabh Homoeopathic Medical College", "country": "India", "domains": ["tshmc.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tumkuruniversity.ac.in/"], "name": "Tumkur University", "country": "India", "domains": ["tumkuruniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tvuni.in/"], "name": "Thiruvalluvar University", "country": "India", "domains": ["tvuni.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://uasbng.kar.nic.in/"], "name": "University of Agricultural Sciences, Bangalore", "country": "India", "domains": ["uasbng.kar.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.uasd.net/"], "name": "University of Agricultural Sciences, Dharwad", "country": "India", "domains": ["uasd.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.uktech.ac.in/"], "name": "Uttarakhand Technical University", "country": "India", "domains": ["uktech.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.uma.ac.in/"], "name": "University of Media Arts", "country": "India", "domains": ["uma.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://unical.ac.in/"], "name": "University of Calicut", "country": "India", "domains": ["unical.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.unigoa.ac.in/"], "name": "Goa University", "country": "India", "domains": ["unigoa.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.uni-mysore.ac.in/"], "name": "University of Mysore", "country": "India", "domains": ["uni-mysore.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.unipune.ernet.in/"], "name": "University of Pune", "country": "India", "domains": ["unipune.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.uniraj.org/"], "name": "University of Rajasthan", "country": "India", "domains": ["uniraj.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.unishivaji.ac.in/"], "name": "Shivaji University", "country": "India", "domains": ["unishivaji.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.unom.ac.in/"], "name": "University of Madras", "country": "India", "domains": ["unom.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.uohyd.ernet.in/"], "name": "University of Hyderabad", "country": "India", "domains": ["uohyd.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.uok.ac.in/"], "name": "University of Kota", "country": "India", "domains": ["uok.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.uor.org/"], "name": "University of Roorkee", "country": "India", "domains": ["uor.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.uou.ac.in/"], "name": "Uttarakhand Open University", "country": "India", "domains": ["uou.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.uptu.ac.in/"], "name": "Uttar Pradesh Technical University", "country": "India", "domains": ["uptu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.utkaluniv.org/"], "name": "Utkal University", "country": "India", "domains": ["utkaluniv.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://vbspu.ac.in/"], "name": "VBS Purvanchal University", "country": "India", "domains": ["vbspu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.vbu.co.in/"], "name": "Vinoba Bhave University", "country": "India", "domains": ["vbu.co.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.vidyasagar.ac.in/"], "name": "Vidyasagar University", "country": "India", "domains": ["vidyasagar.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.vignanuniversity.org/"], "name": "Vignan University", "country": "India", "domains": ["vignanuniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.vikramuniversity.org/"], "name": "Vikram University", "country": "India", "domains": ["vikramuniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.vinayakamissions.com/"], "name": "Vinayaka Mission's Research Foundation-Deemed University", "country": "India", "domains": ["vinayakamissions.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.visva-bharati.ac.in/"], "name": "Visva-Bharati University", "country": "India", "domains": ["visva-bharati.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.vit.ac.in/"], "name": "Vellore Institute of Technology", "country": "India", "domains": ["vit.ac.in"], "state-province": "Tamil Nadu"}, {"alpha_two_code": "IN", "web_pages": ["http://www.vksu-ara.org/"], "name": "Veer Kunwar Singh University", "country": "India", "domains": ["vksu-ara.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.vmou.ac.in/"], "name": "Vardhaman Mahaveer Open University", "country": "India", "domains": ["vmou.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.vnitnagpur.ac.in/"], "name": "Visvesvaraya National Institute of Technology", "country": "India", "domains": ["vnitnagpur.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.vssut.ac.in/"], "name": "Veer Surendra Sai University of Technology", "country": "India", "domains": ["vssut.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.vtu.ac.in/"], "name": "Visvesvaraya Technological University", "country": "India", "domains": ["vtu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.wbuafs.nic.in/"], "name": "West Bengal University of Animal and Fishery Sciences", "country": "India", "domains": ["wbuafs.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.wbut.net/"], "name": "West Bengal University of Technology", "country": "India", "domains": ["wbut.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ycmou.com/"], "name": "Yashawantrao Chavan Maharashtra Open University", "country": "India", "domains": ["ycmou.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ysparmaruniversity.org/"], "name": "Dr. YS Parmar University of Horticulture and Forestry", "country": "India", "domains": ["ysparmaruniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.charusat.ac.in/"], "name": "Charotar University of Science and Technology", "country": "India", "domains": ["charusat.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.nuv.ac.in/"], "name": "Navrachana University", "country": "India", "domains": ["nuv.ac.in"], "state-province": "Gujarat"}]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-9754414eb8d4> in <module>()
# ...

# %%
ulist='''
[{"alpha_two_code": "IN", "web_pages": ["http://www.davietjal.org/"], "name": "DAV Institute of Engineering & Technology", "country": "India", "domains": ["davietjal.org"], "state-province": "Punjab"}, {"alpha_two_code": "IN", "web_pages": ["http://www.lpu.in/"], "name": "Lovely Professional University", "country": "India", "domains": ["lpu.in"], "state-province": "Punjab"}, {"alpha_two_code": "IN", "web_pages": ["https://somaiya.edu/"], "name": "Somaiya Vidyavihar", "country": "India", "domains": ["somaiya.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ncuindia.edu/"], "name": "NorthCap University", "country": "India", "domains": ["ncuindia.edu"], "state-province": "Haryana"}, {"alpha_two_code": "IN", "web_pages": ["http://www.ddu.ac.in/"], "name": "Dharamsinh Desai University", "country": "India", "domains": ["ddu.ac.in"], "state-province": "Gujarat"}, {"alpha_two_code": "IN", "web_pages": ["http://ntruhs.ap.nic.in/"], "name": "University of Health Sciences Andhra Pradesh", "country": "India", "domains": ["ntruhs.ap.nic.in"], "state-province": "Andhra Pradesh"}, {"alpha_two_code": "IN", "web_pages": ["http://www.aaidu.org/"], "name": "Allahabad Agricultural Institute, Deemed University", "country": "India", "domains": ["aaidu.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.aau.ac.in/"], "name": "Assam Agricultural University", "country": "India", "domains": ["aau.ac.in"], "state-province": "Assam"}, {"alpha_two_code": "IN", "web_pages": ["http://www.ahduni.edu.in/"], "name": "Ahmedabad University", "country": "India", "domains": ["ahduni.edu.in"], "state-province": "Gujarat"}, {"alpha_two_code": "IN", "web_pages": ["http://www.aiims.ac.in/"], "name": "All India Institute of Medical Sciences", "country": "India", "domains": ["aiims.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.aisectuniversity.ac.in/"], "name": "AISECT University", "country": "India", "domains": ["aisectuniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.alagappauniversity.ac.in/"], "name": "Alagappa University", "country": "India", "domains": ["alagappauniversity.ac.in"], "state-province": "Tamil Nadu"}, {"alpha_two_code": "IN", "web_pages": ["http://www.alldunivpio.org/"], "name": "Allahabad University", "country": "India", "domains": ["alldunivpio.org"], "state-province": "Uttar Pradesh"}, {"alpha_two_code": "IN", "web_pages": ["http://www.altmeduniversity.com/"], "name": "Open International University for Alternative Medicines", "country": "India", "domains": ["altmeduniversity.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.altmedworld.net/"], "name": "Indian Board of Alternative Medicine", "country": "India", "domains": ["altmedworld.net"], "state-province": "West Bengal"}, {"alpha_two_code": "IN", "web_pages": ["http://www.amity.edu/"], "name": "Amity University", "country": "India", "domains": ["amity.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.amrita.edu/"], "name": "Amrita Vishwa Vidyapeetham (Deemed University)", "country": "India", "domains": ["amrita.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.amtuni.com/"], "name": "Amravati University", "country": "India", "domains": ["amtuni.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.amu.ac.in/"], "name": "Aligarh Muslim University", "country": "India", "domains": ["amu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.andhrauniversity.info/"], "name": "Andhra University", "country": "India", "domains": ["andhrauniversity.info"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.angrau.net/"], "name": "Acharya Ranga Agricultural University", "country": "India", "domains": ["angrau.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.annamalaiuniversity.ac.in/"], "name": "Annamalai University", "country": "India", "domains": ["annamalaiuniversity.ac.in"], "state-province": "Tamil Nadu"}, {"alpha_two_code": "IN", "web_pages": ["http://www.annauniv.edu.in/"], "name": "Anna University of Technology, Tirunelveli", "country": "India", "domains": ["annauniv.edu.in"], "state-province": "Tamil Nadu"}, {"alpha_two_code": "IN", "web_pages": ["http://www.annauniv.edu/"], "name": "Anna University", "country": "India", "domains": ["annauniv.edu"], "state-province": "Tamil Nadu"}, {"alpha_two_code": "IN", "web_pages": ["http://www.apsurewa.nic.in/"], "name": "Awadhesh Pratap Singh University", "country": "India", "domains": ["apsurewa.nic.in"], "state-province": "Madhya Pradesh"}, {"alpha_two_code": "IN", "web_pages": ["http://www.aryainstitutejpr.com/"], "name": "ARYA Institute of Engineering & Technology", "country": "India", "domains": ["aryainstitutejpr.com"], "state-province": "Rajasthan"}, {"alpha_two_code": "IN", "web_pages": ["http://www.assamuniversity.nic.in/"], "name": "Assam University", "country": "India", "domains": ["assamuniversity.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ayurveduniversity.com/"], "name": "Gujarat Ayurved University", "country": "India", "domains": ["ayurveduniversity.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bamu.net/"], "name": "Dr. Babasaheb Ambedkar Marathwada Universtiy", "country": "India", "domains": ["bamu.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bamu.nic.in/"], "name": "Berhampur University", "country": "India", "domains": ["bamu.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.banasthali.org/"], "name": "Banasthali University", "country": "India", "domains": ["banasthali.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bankurauniv.com/"], "name": "Bankura University", "country": "India", "domains": ["bankurauniv.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bau.nic.in/"], "name": "Birsa Agricultural University", "country": "India", "domains": ["bau.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bbauindia.org/"], "name": "Babasaheb Bhimrao Ambedkar University", "country": "India", "domains": ["bbauindia.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bckv.edu.in/"], "name": "Bidhan Chandra Agricultural University", "country": "India", "domains": ["bckv.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bdu.ernet.in/"], "name": "Bharathidasan University", "country": "India", "domains": ["bdu.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.becs.ac.in/"], "name": "Bengal Engineering College", "country": "India", "domains": ["becs.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://bengaluruuniversity.com/"], "name": "Bangalore University", "country": "India", "domains": ["bengaluruuniversity.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bhagwantuniversity.com/"], "name": "Bhagwant University", "country": "India", "domains": ["bhagwantuniversity.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bharathi.ernet.in/"], "name": "Bharathiar University", "country": "India", "domains": ["bharathi.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bharathuniv.com/"], "name": "Bharath Institue Of Higher Education & Research", "country": "India", "domains": ["bharathuniv.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bharatividyapeeth.edu/"], "name": "Bharati Vidyapeeth University", "country": "India", "domains": ["bharatividyapeeth.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bhavuni.edu/"], "name": "Bhavnagar University", "country": "India", "domains": ["bhavuni.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bhu.ac.in/"], "name": "Banaras Hindu University", "country": "India", "domains": ["bhu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://bhub.ori.nic.in/ouat/"], "name": "Orissa University of Agriculture and Technology", "country": "India", "domains": ["bhub.ori.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://bitmesraranchi.org/"], "name": "Birla Institute of Technology, Ranchi", "country": "India", "domains": ["bitmesraranchi.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bits-pilani.ac.in/"], "name": "Birla Institute of Technology and Science", "country": "India", "domains": ["bits-pilani.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bnmu.in/"], "name": "Bhupendra Narayan Mandal University", "country": "India", "domains": ["bnmu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bput.org/"], "name": "Biju Pattnaik University of Technology", "country": "India", "domains": ["bput.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.brabu.net/"], "name": "B. R. Ambedkar Bihar University", "country": "India", "domains": ["brabu.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.braou.ac.in/"], "name": "Dr. B.R. Ambedkar Open University", "country": "India", "domains": ["braou.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitj.ac.in/"], "name": "Dr. B. R. Ambedkar National Institute of Technology Jalandhar", "country": "India", "domains": ["nitj.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.brauagra.com/"], "name": "Dr. Bhim Rao Abdekar University", "country": "India", "domains": ["brauagra.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bsauniv.ac.in/"], "name": "B. S. Abdur Rahman University", "country": "India", "domains": ["bsauniv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bubhopal.nic.in/"], "name": "Barkatullah University", "country": "India", "domains": ["bubhopal.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.bundelkhanduniversity.org/"], "name": "Bundelkhand University", "country": "India", "domains": ["bundelkhanduniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.burdwanuniversity.ac.in/"], "name": "University of Burdwan", "country": "India", "domains": ["burdwanuniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.caluniv.ac.in/"], "name": "University of Calcutta", "country": "India", "domains": ["caluniv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.cau.org.in/"], "name": "Central Agricultural University", "country": "India", "domains": ["cau.org.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ccsuniversity.ac.in/"], "name": "Chaudhary Charan Singh University", "country": "India", "domains": ["ccsuniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ccsuniversity.org/"], "name": "Ch. Charan Singh University", "country": "India", "domains": ["ccsuniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.cesbm.ac.in/"], "name": "Center for Entrepreneurship and Small Business Management", "country": "India", "domains": ["cesbm.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.christuniversity.in/"], "name": "Christ University", "country": "India", "domains": ["christuniversity.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ciefl.org/"], "name": "Central Institute of English and Foreign Languages", "country": "India", "domains": ["ciefl.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.cife.edu.in/"], "name": "Central Institute of Fisheries Education", "country": "India", "domains": ["cife.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.cihts.ac.in/"], "name": "Central Institute of Higher Tibetan Studies", "country": "India", "domains": ["cihts.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.cmjuniversity.edu.in/"], "name": "CMJ University", "country": "India", "domains": ["cmjuniversity.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.csauk.ac.in/"], "name": "Chandra Shekhar Azad University of Agriculture and Technology", "country": "India", "domains": ["csauk.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.cusat.ac.in/"], "name": "Cochin University of Science and Technology", "country": "India", "domains": ["cusat.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.cvru.ac.in/"], "name": "Dr. C.V. Raman University", "country": "India", "domains": ["cvru.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.da-iict.org/"], "name": "Dhirubhai Ambani Institute of Information and Communication Technology", "country": "India", "domains": ["da-iict.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.darulhuda.com/"], "name": "Darul Huda Islamic University", "country": "India", "domains": ["darulhuda.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.davuniversity.org/"], "name": "Dav University", "country": "India", "domains": ["davuniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.davv.ac.in/"], "name": "Devi Ahilya University of Indore", "country": "India", "domains": ["davv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.dbatechuni.org/"], "name": "Dr. Babasaheb Ambedkar Technological University", "country": "India", "domains": ["dbatechuni.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.dbskkv.org/"], "name": "Konkan Agricultural University", "country": "India", "domains": ["dbskkv.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://dbs.tn.nic.in/tnau/"], "name": "Tamil Nadu Agricultural University", "country": "India", "domains": ["dbs.tn.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.dceonline.net/"], "name": "Delhi College of Engineering (DCE)", "country": "India", "domains": ["dceonline.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ddugu.edu.in/"], "name": "Deen Dayal Upadhyay Gorakhpur University", "country": "India", "domains": ["ddugu.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.deccancollegepune.ac.in/"], "name": "Deccan College Postgraduate and Research Institute", "country": "India", "domains": ["deccancollegepune.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.dei.ac.in/"], "name": "Dayalbagh Educational Institute", "country": "India", "domains": ["dei.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.dibru.ernet.in/"], "name": "Dibrugarh University", "country": "India", "domains": ["dibru.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.dravidianuniversity.ac.in/"], "name": "Dravidian University", "country": "India", "domains": ["dravidianuniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.du.ac.in/"], "name": "University of Delhi", "country": "India", "domains": ["du.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.dypatiluniversity.org/"], "name": "Dr. D.Y. Patil University", "country": "India", "domains": ["dypatiluniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.eiilmuniversity.ac.in/"], "name": "Eiilm University", "country": "India", "domains": ["eiilmuniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.fatimacollege.net/"], "name": "Fatima mata national college kollam kerala", "country": "India", "domains": ["fatimacollege.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://fri.icfre.gov.in/"], "name": "Forest Research Institute Dehradun", "country": "India", "domains": ["fri.icfre.gov.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.gbpuat.ac.in/"], "name": "Govind Ballabh Pant University of Agriculture and Technology", "country": "India", "domains": ["gbpuat.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ggu.ac.in/"], "name": "Guru Ghasidas University", "country": "India", "domains": ["ggu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.gipe.ernet.in/"], "name": "Gokhale Institute of Politics and Economics", "country": "India", "domains": ["gipe.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.gitam.edu/"], "name": "Gandhi Institute of Technology and Managment", "country": "India", "domains": ["gitam.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.gju.ernet.in/"], "name": "Guru Jambeshwar University", "country": "India", "domains": ["gju.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.gkvharidwar.org/"], "name": "Gurukula Kangri University", "country": "India", "domains": ["gkvharidwar.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.gnduonline.org/"], "name": "Guru Nanak Dev University", "country": "India", "domains": ["gnduonline.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.government.ind.in/"], "name": "Global Open University , Nagaland", "country": "India", "domains": ["government.ind.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.gtu.ac.in/"], "name": "Gujarat Technological University Ahmedabad", "country": "India", "domains": ["gtu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.gujaratuniversity.org.in/"], "name": "Gujarat University Ahmedabad", "country": "India", "domains": ["gujaratuniversity.org.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.gulbargauniversity.kar.nic.in/"], "name": "Gulbarga University", "country": "India", "domains": ["gulbargauniversity.kar.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.gu.nic.in/"], "name": "Gauhati University", "country": "India", "domains": ["gu.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.gurukuluniversity.org/"], "name": "Gurukul University", "country": "India", "domains": ["gurukuluniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://hau.ernet.in/"], "name": "CCS Haryana Agricultural University", "country": "India", "domains": ["hau.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.hau.ernet.in/"], "name": "Chaudhary Charan Singh Haryana Agricultural University", "country": "India", "domains": ["hau.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://hillagric.ernet.in/"], "name": "Himachal Pradesh Agricultural University", "country": "India", "domains": ["hillagric.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.hnbgu.ac.in/"], "name": "Hemwati Nandan Bahuguna Garhwal University", "country": "India", "domains": ["hnbgu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.hnluraipur.com/"], "name": "Hidayatullah National Law University, Raipur", "country": "India", "domains": ["hnluraipur.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.hostindia.com/srmc/"], "name": "Sri Ramachardra Medical College and Research Institute", "country": "India", "domains": ["hostindia.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://hpuniv.nic.in/"], "name": "Himachal Pradesh University", "country": "India", "domains": ["hpuniv.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iari.ernet.in/"], "name": "Indian Agricultural Research Institute", "country": "India", "domains": ["iari.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iaseduniv.org/"], "name": "IASE (Institute of Advanced Studies) Deemed University", "country": "India", "domains": ["iaseduniv.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.icfai.org/"], "name": "ICFAI University", "country": "India", "domains": ["icfai.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.iudehradun.edu.in/"], "name": "ICFAI University, Dehradun", "country": "India", "domains": ["iudehradun.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.iutripura.edu.in/"], "name": "ICFAI University, Tripura", "country": "India", "domains": ["iutripura.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.iusikkim.edu.in/"], "name": "ICFAI University, Sikkim", "country": "India", "domains": ["iusikkim.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.iumizoram.edu.in/"], "name": "ICFAI University, Mizoram", "country": "India", "domains": ["iumizoram.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.iumeghalaya.edu.in/"], "name": "ICFAI University, Meghalaya", "country": "India", "domains": ["iumeghalaya.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.iujharkhand.edu.in/"], "name": "ICFAI University, Jharkhand", "country": "India", "domains": ["iujharkhand.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.iunagaland.edu.in/"], "name": "ICFAI University, Nagaland", "country": "India", "domains": ["iunagaland.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.iujaipur.edu.in/"], "name": "ICFAI University, Jaipur", "country": "India", "domains": ["iujaipur.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.iuraipur.edu.in/"], "name": "ICFAI University, Raipur", "country": "India", "domains": ["iuraipur.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.iuhimachal.edu.in/"], "name": "ICFAI University, Himachal Pradesh", "country": "India", "domains": ["iuhimachal.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.ifheindia.org/"], "name": "ICFAI University, Hyderabad", "country": "India", "domains": ["ifheindia.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.igau.edu.in/"], "name": "Indira Gandhi Agricultural University", "country": "India", "domains": ["igau.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.igidr.ac.in/"], "name": "Indira Gandhi Institute of Development and Research", "country": "India", "domains": ["igidr.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.igims.org/"], "name": "Indira Gandhi Institute of Medical Sciences", "country": "India", "domains": ["igims.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ignou.ac.in/"], "name": "Indira Gandhi National Open University", "country": "India", "domains": ["ignou.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iiita.com/"], "name": "Indian Institute of Information Technology", "country": "India", "domains": ["iiita.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iiitmk.ac.in/"], "name": "Indian Institute of Information Technology and Management - Kerala", "country": "India", "domains": ["iiitmk.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iiitm.ac.in/"], "name": "Indian Institute of Information Technology and Management - Gwalior", "country": "India", "domains": ["iiitm.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iiitd.ac.in/"], "name": "Indraprastha Institute of Information Technology, Delhi", "country": "India", "domains": ["iiitd.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["www.isquareit.ac.in/"], "name": "International Institute of Information Technology, Pune", "country": "India", "domains": ["squareit.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["www.iiit-bh.ac.in/"], "name": "International Institute of Information Technology, Bhubaneswar", "country": "India", "domains": ["iiit-bh.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["www.iiitb.ac.in/"], "name": "International Institute of Information Technology, Bangalore", "country": "India", "domains": ["iiitb.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iimtrichy.ac.in/"], "name": "Indian Institute of Management, Tiruchirappalli", "country": "India", "domains": ["iimtrichy.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iimtrichy.ac.in/"], "name": "Indian Institute of Information Technology, Guwahati", "country": "India", "domains": ["iiitg.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://iiitvadodara.ac.in/"], "name": "Indian Institute of Information Technology, Vadodara", "country": "India", "domains": ["iiitvadodara.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://iiitkota.ac.in/"], "name": "Indian Institute of Information Technology, Kota", "country": "India", "domains": ["iiitkota.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iipsindia.org/"], "name": "International Institute for Population Sciences", "country": "India", "domains": ["iipsindia.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iisc.ernet.in/"], "name": "Indian Institute of Science", "country": "India", "domains": ["iisc.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iitb.ac.in/"], "name": "Indian Institute of Technology, Bombay", "country": "India", "domains": ["iitb.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iitd.ernet.in/"], "name": "Indian Institute of Technology, Delhi", "country": "India", "domains": ["iitd.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://iitgn.ac.in/"], "name": "Indian Institute of Technology, Gandhinagar", "country": "India", "domains": ["iitgn.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iitg.ernet.in/", "http://www.iitg.ac.in/"], "name": "Indian Institute of Technology, Guwahati", "country": "India", "domains": ["iitg.ernet.in", "iitg.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iith.ac.in/"], "name": "Indian Institute of Technology, Hyderabad", "country": "India", "domains": ["iith.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iitk.ac.in/"], "name": "Indian Institute of Technology, Kanpur", "country": "India", "domains": ["iitk.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iitkgp.ernet.in/"], "name": "Indian Institute of Technology, Kharagpur", "country": "India", "domains": ["iitkgp.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iitm.ac.in/"], "name": "Indian Institute of Technology, Madras", "country": "India", "domains": ["iitm.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.mitindia.edu/en/"], "name": "Madras Institute of Technology", "country": "India", "domains": ["mitindia.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iitr.ac.in/"], "name": "Indian Institute of Technology, Roorkee", "country": "India", "domains": ["iitr.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iitp.ac.in/"], "name": "Indian Institute of Technology, Patna", "country": "India", "domains": ["iitp.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iiti.ac.in/"], "name": "Indian Institute of Technology, Indore", "country": "India", "domains": ["iiti.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iitj.ac.in/"], "name": "Indian Institute of Technology, Jodhpur", "country": "India", "domains": ["iitj.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iksvv.com/"], "name": "University of Music and Fine Arts", "country": "India", "domains": ["iksvv.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ilidelhi.org/"], "name": "Indian Law Institue", "country": "India", "domains": ["ilidelhi.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.indusuni.ac.in/"], "name": "Indus University", "country": "India", "domains": ["indusuni.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.integraluniversity.ac.in/"], "name": "Integral University", "country": "India", "domains": ["integraluniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ipu.ac.in/"], "name": "Guru Gobind Singh Indraprastha University", "country": "India", "domains": ["ipu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://isbm.org.in/"], "name": "Indian School of Business Management and Administration", "country": "India", "domains": ["isbm.org.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.isical.ac.in/"], "name": "Indian Statistical Institute", "country": "India", "domains": ["isical.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ismdhanbad.ac.in/"], "name": "Indian School of Mines (ISM)", "country": "India", "domains": ["ismdhanbad.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.itmindia.edu/"], "name": "Institute of Technology and Management", "country": "India", "domains": ["itmindia.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.iur.ac.in/"], "name": "Indian University", "country": "India", "domains": ["iur.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ivri.nic.in/"], "name": "Indian Veterinary Research Institute", "country": "India", "domains": ["ivri.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jadavpur.edu/"], "name": "Jadavpur University", "country": "India", "domains": ["jadavpur.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jainuniversity.org/"], "name": "First Global University to teaching Jainism", "country": "India", "domains": ["jainuniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jamiahamdard.edu/"], "name": "Jamia Hamdard University", "country": "India", "domains": ["jamiahamdard.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jammuvarsity.org/"], "name": "University of Jammu", "country": "India", "domains": ["jammuvarsity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jiit.ac.in/"], "name": "Jaypee Institute of Information Technology", "country": "India", "domains": ["jiit.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jiwaji.edu/"], "name": "Jiwaji University", "country": "India", "domains": ["jiwaji.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://jmi.nic.in/"], "name": "Jamia Millia Islamia University", "country": "India", "domains": ["jmi.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jncasr.ac.in/"], "name": "Jawaharlal Nehru Centre for Advanced  Scientific Research", "country": "India", "domains": ["jncasr.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jnkvv.nic.in/"], "name": "Jawaharlal Nehru Agricultural University", "country": "India", "domains": ["jnkvv.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jntu.ac.in/"], "name": "Jawaharlal Nehru Technological University", "country": "India", "domains": ["jntu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jnu.ac.in/"], "name": "Jawaharlal Nehru University", "country": "India", "domains": ["jnu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jnujaipur.ac.in/"], "name": "Jaipur National University", "country": "India", "domains": ["jnujaipur.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jodhpurnationaluniversity.com/"], "name": "Jodhpur National University", "country": "India", "domains": ["jodhpurnationaluniversity.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://jpv.bih.nic.in/"], "name": "Jai Prakash University", "country": "India", "domains": ["jpv.bih.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jrnrvu.org/"], "name": "Rajasthan Vidyapeeth University", "country": "India", "domains": ["jrnrvu.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.jvbi.ac.in/"], "name": "Jain Vishva Bharati Institute", "country": "India", "domains": ["jvbi.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kalingauniversity.com/"], "name": "Kalinga University", "country": "India", "domains": ["kalingauniversity.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kanchiuniv.ac.in/"], "name": "Sri Chandrasekharendra Saraswathi Viswa Mahavidyalaya", "country": "India", "domains": ["kanchiuniv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kannadauniversity.org/"], "name": "Kannada University", "country": "India", "domains": ["kannadauniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kannuruniversity.ac.in/"], "name": "Kannur University", "country": "India", "domains": ["kannuruniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kanpuruniversity.org/"], "name": "Chhatrapati Shahu Ji Maharaj University", "country": "India", "domains": ["kanpuruniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kanpuruniversity.org/"], "name": "Kanpur University", "country": "India", "domains": ["kanpuruniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.karnatakastateopenuniversity.in/"], "name": "Karnataka State Open University", "country": "India", "domains": ["karnatakastateopenuniversity.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.karpagamuniv.com/"], "name": "Karpagam University", "country": "India", "domains": ["karpagamuniv.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.karunya.edu/"], "name": "Karunya Institute Of Technology ( Deemed University)", "country": "India", "domains": ["karunya.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://kashmiruniversity.net/"], "name": "University of Kashmir", "country": "India", "domains": ["kashmiruniversity.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kau.edu/"], "name": "Kerala Agricultural University", "country": "India", "domains": ["kau.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.keralauniversity.ac.in/"], "name": "University of Kerala", "country": "India", "domains": ["keralauniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://kimi.kohinoor.ac.in/"], "name": "Kohinoor School of Hospitality Management", "country": "India", "domains": ["kimi.kohinoor.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.klyuniv.ac.in/"], "name": "University of Kalyani", "country": "India", "domains": ["klyuniv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.krishnauniversity.ac.in/"], "name": "Krishna University", "country": "India", "domains": ["krishnauniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ksdsu.edu.in/"], "name": "Kameshwar Singh Darbhanga Sanskrit University", "country": "India", "domains": ["ksdsu.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kslu.ac.in/"], "name": "Karnataka State Law University", "country": "India", "domains": ["kslu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kud.ac.in/"], "name": "Karnatak University", "country": "India", "domains": ["kud.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kufos.ac.in/"], "name": "Kerala University of Fisheries and Ocean Sciences", "country": "India", "domains": ["kufos.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kukinfo.com/"], "name": "Kurukshetra University", "country": "India", "domains": ["kukinfo.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kct.ac.in/"], "name": "Kumaraguru College of Technology", "country": "India", "domains": ["kct.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kumaununiversity.org/"], "name": "Kumaun University", "country": "India", "domains": ["kumaununiversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kuvempu.ac.in/"], "name": "Kuvempu University", "country": "India", "domains": ["kuvempu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.kuwarangal.com/"], "name": "Kakatiya University", "country": "India", "domains": ["kuwarangal.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ldceahd.org/"], "name": "L.D.College of Engineering", "country": "India", "domains": ["ldceahd.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.lnipe.edu/"], "name": "Lakshmibai National Institute of Physical Education", "country": "India", "domains": ["lnipe.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://lnmu.bih.nic.in/"], "name": "Lalit Narayan Mithila University", "country": "India", "domains": ["lnmu.bih.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.lucknowuniv.org/"], "name": "University of Lucknow", "country": "India", "domains": ["lucknowuniv.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.macfast.org/"], "name": "Mar Athanasios College for Advanced Studies", "country": "India", "domains": ["macfast.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.magadhuniversity.org/"], "name": "Magadh University", "country": "India", "domains": ["magadhuniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mangaloreuniversity.ac.in/"], "name": "Mangalore University", "country": "India", "domains": ["mangaloreuniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.manipal.edu/"], "name": "Manipal University", "country": "India", "domains": ["manipal.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.manipur.nic.in/maniuniversity.htm"], "name": "Manipur University", "country": "India", "domains": ["manipur.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.manuu.ac.in/"], "name": "Moulana Azad national Urdu University", "country": "India", "domains": ["manuu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mcu.ac.in/"], "name": "Makanlal Chutur Vedi University", "country": "India", "domains": ["mcu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mcu.ac.in/"], "name": "Makhanlal Chaturvedi National University of Journalism and Communication", "country": "India", "domains": ["mcu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mdsuajmer.ac.in/"], "name": "Maharshi Dayanand Sarswati University Ajmer", "country": "India", "domains": ["mdsuajmer.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mdurohtak.com/"], "name": "Maharishi Dayanand University, Rohtak (Haryana )", "country": "India", "domains": ["mdurohtak.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mgkvp.ac.in/"], "name": "Mahatma Gandhi Kashi Vidyapith", "country": "India", "domains": ["mgkvp.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mgsubikaner.ac.in/"], "name": "Maharaja Ganga Singh University, Bikaner", "country": "India", "domains": ["mgsubikaner.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mgu.ac.in/"], "name": "Mahatma Gandhi University, Kerala", "country": "India", "domains": ["mgu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mjpru.ac.in/"], "name": "Mahatma Jyotiba Phule Rohilkhand University Bareilly", "country": "India", "domains": ["mjpru.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mkuhyd.com/"], "name": "Madurai Kamaraj University", "country": "India", "domains": ["mkuhyd.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://mkv2.mah.nic.in/"], "name": "Marathwada Agricultural University", "country": "India", "domains": ["mkv2.mah.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mlsu.ac.in/"], "name": "Mohan Lal Sukhadia University", "country": "India", "domains": ["mlsu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mnnit.ac.in/"], "name": "Motilal Nehru National Institute Of Technology", "country": "India", "domains": ["mnnit.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mpbou.org/"], "name": "Madhya Pradesh Bhoj (Open) University", "country": "India", "domains": ["mpbou.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://mpkv.mah.nic.in/"], "name": "Mahatma Phule Agricultural University", "country": "India", "domains": ["mpkv.mah.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.msubaroda.ac.in/"], "name": "Maharaja Sayajirao University of Baroda", "country": "India", "domains": ["msubaroda.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mu.ac.in/"], "name": "University of Mumbai", "country": "India", "domains": ["mu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nagarjunauniversity.ac.in/"], "name": "Acharya Nagarjuna University", "country": "India", "domains": ["nagarjunauniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nagauniv.org.in/"], "name": "Nagaland University", "country": "India", "domains": ["nagauniv.org.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nagpur-university.com/"], "name": "Nagpur University", "country": "India", "domains": ["nagpur-university.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nalandaopenuniversity.info/"], "name": "Nalanda Open University", "country": "India", "domains": ["nalandaopenuniversity.info"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nationalmuseumindia.org/nmi/index.htm"], "name": "National Museum Institute of History of Art, Conservation and Museology", "country": "India", "domains": ["nationalmuseumindia.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nbu.ac.in/"], "name": "University of North Bengal", "country": "India", "domains": ["nbu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://ndri.nic.in/"], "name": "National Dairy Research Institute", "country": "India", "domains": ["ndri.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nduat.nic.in/"], "name": "Narendra Deva University of Agriculture and Technology", "country": "India", "domains": ["nduat.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nehu.ac.in/"], "name": "North Eastern Hill University", "country": "India", "domains": ["nehu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ngu.ac.in/"], "name": "Hemchandracharay North Gujarat University", "country": "India", "domains": ["ngu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nimhans.kar.nic.in/"], "name": "National Institute of Mental Health and Neuro Sciences", "country": "India", "domains": ["nimhans.kar.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://nims.ap.nic.in/"], "name": "Nizam's Institute of Medical Sciences", "country": "India", "domains": ["nims.ap.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nims.net.in/"], "name": "Institute of Management Studies", "country": "India", "domains": ["nims.net.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nirmauni.ac.in/"], "name": "Nirma University", "country": "India", "domains": ["nirmauni.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitie.edu/"], "name": "National Institute of Industrial Engineering", "country": "India", "domains": ["nitie.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nita.ac.in/"], "name": "National Institute of Technology Agartala", "country": "India", "domains": ["nita.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitandhra.ac.in/"], "name": "National Institute of Technology Andhra Pradesh", "country": "India", "domains": ["nitandhra.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitap.in/"], "name": "National Institute of Technology Arunachal Pradesh", "country": "India", "domains": ["nitap.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitc.ac.in/"], "name": "National Institute of Technology Calicut", "country": "India", "domains": ["nitc.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitdelhi.ac.in/"], "name": "National Institute of Technology Delhi", "country": "India", "domains": ["nitdelhi.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitdgp.ac.in/"], "name": "National Institute of Technology Durgapur", "country": "India", "domains": ["nitdgp.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitgoa.ac.in/"], "name": "National Institute of Technology Goa", "country": "India", "domains": ["nitgoa.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nith.ac.in/"], "name": "National Institute of Technology Hamirpur", "country": "India", "domains": ["nith.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitjsr.ac.in/"], "name": "National Institute of Technology Jamshedpur", "country": "India", "domains": ["nitjsr.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitkkr.net/"], "name": "National Institute of Technology Kurukshetra", "country": "India", "domains": ["nitkkr.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitmanipur.ac.in"], "name": "National Institute of Technology Manipur", "country": "India", "domains": ["nitmanipur.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitm.ac.in"], "name": "National Institute of Technology Meghalaya", "country": "India", "domains": ["nitm.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitmz.ac.in"], "name": "National Institute of Technology Mizoram", "country": "India", "domains": ["nitmz.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitnagaland.ac.in"], "name": "National Institute of Technology Nagaland", "country": "India", "domains": ["nitnagaland.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitp.ac.in"], "name": "National Institute of Technology Patna", "country": "India", "domains": ["nitp.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitpy.ac.in"], "name": "National Institute of Technology Puducherry", "country": "India", "domains": ["nitpy.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitrr.ac.in"], "name": "National Institute of Technology Raipur", "country": "India", "domains": ["nitrr.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitrkl.ac.in/"], "name": "National Institute of Technology Rourkela", "country": "India", "domains": ["nitrkl.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitsikkim.ac.in/"], "name": "National Institute of Technology Sikkim", "country": "India", "domains": ["nitsikkim.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nits.ac.in/"], "name": "National Institute of Technology Silchar", "country": "India", "domains": ["nits.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitsri.net/"], "name": "National Institute of Technology Srinagar", "country": "India", "domains": ["nitsri.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitk.ac.in/"], "name": "National Institute of Technology Surathkal", "country": "India", "domains": ["nitk.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitt.edu/"], "name": "National Institute of Technology Trichy", "country": "India", "domains": ["nitt.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nituk.ac.in/"], "name": "National Institute of Technology Uttarakhand", "country": "India", "domains": ["nituk.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nitw.ernet.in/"], "name": "National Institute of Technology Warangal", "country": "India", "domains": ["nitw.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nls.ac.in/"], "name": "National Law School of India University", "country": "India", "domains": ["nls.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nmims.edu/"], "name": "Narsee Monjee Institute of Management Studies", "country": "India", "domains": ["nmims.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nmu.ac.in/"], "name": "North Maharashtra University", "country": "India", "domains": ["nmu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.nsit.ac.in/"], "name": "Netaji Subhas Institute of Technology", "country": "India", "domains": ["nsit.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.osmania.ac.in/"], "name": "Osmania University", "country": "India", "domains": ["osmania.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.padmavatiwomen-univ.org/"], "name": "Sri Padmavati Women's University", "country": "India", "domains": ["padmavatiwomen-univ.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.pdpu.ac.in/"], "name": "Pandit Deendayal Petroleum University", "country": "India", "domains": ["pdpu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.pau.edu/"], "name": "Punjab Agricultural University", "country": "India", "domains": ["pau.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.pdkv.ac.in/"], "name": "Dr. Panjabrao Deshmukh Krishi Vidyapeeth", "country": "India", "domains": ["pdkv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.paruluniversity.ac.in/"], "name": "Parul University", "country": "India", "domains": ["paruluniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.pec.ac.in/"], "name": "Punjab Engineering College", "country": "India", "domains": ["pec.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.pes.edu/"], "name": "Pes University", "country": "India", "domains": ["pes.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.pgimer.nic.in/"], "name": "Postgraduate lnstitute of Medical Education and Research", "country": "India", "domains": ["pgimer.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.pondiuni.org/"], "name": "Pondicherry University", "country": "India", "domains": ["pondiuni.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.psgtech.edu/"], "name": "PSG College of Technology", "country": "India", "domains": ["psgtech.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ptetjnvu.org/"], "name": "Jai Narain Vyas University", "country": "India", "domains": ["ptetjnvu.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ptu.ac.in/"], "name": "Punjab Technical University", "country": "India", "domains": ["ptu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.puchd.ac.in/"], "name": "Panjab University", "country": "India", "domains": ["puchd.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.punjabiuniversity.ac.in/"], "name": "Punjabi University Patiala", "country": "India", "domains": ["punjabiuniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://puonline.bih.nic.in/"], "name": "Patna University", "country": "India", "domains": ["puonline.bih.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.pusavarsity.org.in/"], "name": "Rajendra Agricultural University", "country": "India", "domains": ["pusavarsity.org.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.rabindrabharatiuniversity.net/"], "name": "Rabindra Bharati University", "country": "India", "domains": ["rabindrabharatiuniversity.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ranchiuniversity.org.in/"], "name": "Ranchi University", "country": "India", "domains": ["ranchiuniversity.org.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.raubikaner.org/"], "name": "Rajasthan Agricultural University, Bikaner", "country": "India", "domains": ["raubikaner.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.rdunijbpin.org/"], "name": "Rani Durgavati University", "country": "India", "domains": ["rdunijbpin.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.rgtu.net/"], "name": "Rajiv Gandhi Technical University (University of Technology of Madhya Pradesh)", "country": "India", "domains": ["rgtu.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.rgu.ac.in/"], "name": "Rajiv Gandhi University", "country": "India", "domains": ["rgu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.riths.ac.in/"], "name": "Rajitlal Institute of Technology & Health Sciences (RITHS)", "country": "India", "domains": ["riths.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.rmlau.ac.in/"], "name": "Dr. Ram Manohar Lohia Avadh University", "country": "India", "domains": ["rmlau.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.rsuniversity.com/"], "name": "Pandit Ravi Shankar Shukla University", "country": "India", "domains": ["rsuniversity.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.rtu.ac.in/"], "name": "Rajasthan Technical University", "country": "India", "domains": ["rtu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ruraluniversity-chitrakoot.org/"], "name": "Mahatma Gandhi Chitrakut Gramoday University", "country": "India", "domains": ["ruraluniversity-chitrakoot.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.sagaruniversity.nic.in/"], "name": "Dr. Hari Singh Gour University, formerly University of Sagar", "country": "India", "domains": ["sagaruniversity.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.sambalpuruniversitypgc.in/"], "name": "Sambalpur University", "country": "India", "domains": ["sambalpuruniversitypgc.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.sanskrit.nic.in/"], "name": "National Sanskrit University", "country": "India", "domains": ["sanskrit.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.sastra.edu/"], "name": "SASTRA Deemed University", "country": "India", "domains": ["sastra.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.sathyabamauniv.ac.in/"], "name": "Sathyabama University", "country": "India", "domains": ["sathyabamauniv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.saurashtrauniversity.edu/"], "name": "Saurashtra University", "country": "India", "domains": ["saurashtrauniversity.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.sce.ac.in/"], "name": "Shanmugha Arts Science Technology and Research Academy", "country": "India", "domains": ["sce.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://sctimst.ker.nic.in/"], "name": "Sree Chitra Tirunal Institute for Medical Sciences and Technology", "country": "India", "domains": ["sctimst.ker.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.sdau.edu.in/"], "name": "Sardarkrushinagar Dantiwada Agricultural University", "country": "India", "domains": ["sdau.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.sgpgi.ac.in/"], "name": "Sanjay Gandhi Postgraduate lnstitute of Medical Sciences", "country": "India", "domains": ["sgpgi.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.sgu.ernet.in/"], "name": "South Gujarat University", "country": "India", "domains": ["sgu.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.shobhituniversity.ac.in/"], "name": "Shobhit University, Meerut", "country": "India", "domains": ["shobhituniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.shridharuniversity.ac.in/"], "name": "Shridhar University", "country": "India", "domains": ["shridharuniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.simhapuriuniv.ac.in/"], "name": "Vikrama Simhapuri University", "country": "India", "domains": ["simhapuriuniv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.siu.edu.in/"], "name": "Symbiosis International University", "country": "India", "domains": ["siu.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.sjsv.nic.in/"], "name": "Shri Jagannath Sanskrit University", "country": "India", "domains": ["sjsv.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.skmu.edu.in/"], "name": "Sido Kanhu Murmu University", "country": "India", "domains": ["skmu.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.skuastkashmir.ac.in/"], "name": "Sher-E-Kashmir University of Agricultural Sciences and Technology", "country": "India", "domains": ["skuastkashmir.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://skuniv.ap.nic.in/"], "name": "Sri Krishnadevaraya University", "country": "India", "domains": ["skuniv.ap.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.slbsrsv.ac.in/"], "name": "Shri Lal Bahadur Shastri Rashtriya Sanskrit Vidyapeetha", "country": "India", "domains": ["slbsrsv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.smkfomra.net/"], "name": "SMK Fomra Institute of Technology", "country": "India", "domains": ["smkfomra.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.smu.edu.in/"], "name": "Sikkim Manipal University of Health, Medical and Technological Sciences", "country": "India", "domains": ["smu.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.sndt.edu/"], "name": "Shreemati Nathibai Damodar Thackersey Women's University", "country": "India", "domains": ["sndt.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.soauniversity.ac.in/"], "name": "Sikha 'O' Anushandhan University", "country": "India", "domains": ["soauniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.southasianuniversity.org/"], "name": "South Asian University", "country": "India", "domains": ["southasianuniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.spa.ac.in/"], "name": "School of Planning and Architecture", "country": "India", "domains": ["spa.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.spuniv.org/"], "name": "Periyar University", "country": "India", "domains": ["spuniv.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.spuvvn.edu/"], "name": "Sardar Patel University", "country": "India", "domains": ["spuvvn.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.srisathyasai.org.in/pages/instts/HighLearn.htm"], "name": "Sri Sathya Sai Institute of Higher Learning", "country": "India", "domains": ["srisathyasai.org.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.srkdc.org/"], "name": "Sree Rama Krishna Degree College", "country": "India", "domains": ["srkdc.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.srmuniv.ac.in/"], "name": "SRM Institute Of Science & Technology ( Deemed University)", "country": "India", "domains": ["srmuniv.ac.in"], "state-province": "Tamil Nadu"}, {"alpha_two_code": "IN", "web_pages": ["http://www.srtmun.org/"], "name": "Swami Ramanand Teerth Marathwada University", "country": "India", "domains": ["srtmun.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ssgmce.org/"], "name": "Sri Sant Gajanan Maharaj College of Engineering", "country": "India", "domains": ["ssgmce.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ssus.ac.in/"], "name": "Sree Sankaracharya University of Sanskrit", "country": "India", "domains": ["ssus.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://ssvv.up.nic.in/"], "name": "Sampurnanand Sanskrit University", "country": "India", "domains": ["ssvv.up.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://su.digitaluniversity.ac/"], "name": "Solapur University", "country": "India", "domains": ["su.digitaluniversity.ac"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.svbpuctm.org/"], "name": "Sardar Vallabhai Patel University of Agriculture Amd Technology", "country": "India", "domains": ["svbpuctm.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.svnit.ac.in/"], "name": "Sardar Vallabhbhai National Institute of Technology", "country": "India", "domains": ["svnit.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://svimstpt.ap.nic.in/"], "name": "Sri Venkateswara Institute of Medical Sciences", "country": "India", "domains": ["svimstpt.ap.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://svuni.ap.nic.in/"], "name": "Sri Venkateswara University", "country": "India", "domains": ["svuni.ap.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tamiluniversity.ac.in/"], "name": "Tamil University", "country": "India", "domains": ["tamiluniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tanuvas.com/"], "name": "Tamil Nadu Veterinary and Animal Sciences University", "country": "India", "domains": ["tanuvas.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tce.edu/"], "name": "Thiagarajar College of Engineering", "country": "India", "domains": ["tce.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.teluguuniversity.ac.in/"], "name": "Potti Sreeramulu Telugu University", "country": "India", "domains": ["teluguuniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.teluguuniversity.ac.in/"], "name": "Telugu University", "country": "India", "domains": ["teluguuniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tezu.ernet.in/"], "name": "Tezpur University", "country": "India", "domains": ["tezu.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.thenewcollege.org/"], "name": "The New College", "country": "India", "domains": ["thenewcollege.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tiet.ac.in/"], "name": "Thapar Institute of Engineering and Technology", "country": "India", "domains": ["tiet.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tiss.edu/"], "name": "Tata Institute of Social Sciences", "country": "India", "domains": ["tiss.edu"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tmbu.org/"], "name": "Tilka Manjhi Bhagalpur University", "country": "India", "domains": ["tmbu.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tmv.edu.in/"], "name": "Tilak Maharashtra Vidyapeeth", "country": "India", "domains": ["tmv.edu.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tndalu.org/"], "name": "Tamil Nadu Dr. Ambedkar Law University", "country": "India", "domains": ["tndalu.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tnmmu.ac.in/"], "name": "Tamil Nadu Dr. M.G.R. Medical University", "country": "India", "domains": ["tnmmu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tnuniv.ac.in/adu/"], "name": "Avinashilingam Institute for Home Science and Higher Education for Women", "country": "India", "domains": ["tnuniv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tnuniv.ac.in/gri/"], "name": "Gandhigram Rural Institute", "country": "India", "domains": ["tnuniv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tnuniv.ac.in/msu/"], "name": "Manonmaniam Sundaranar University", "country": "India", "domains": ["tnuniv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tnuniv.ac.in/mteresa/"], "name": "Mother Teresa Women's University", "country": "India", "domains": ["tnuniv.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.manit.ac.in/"], "name": "Maulana Azad National Institute of Technology Bhopal", "country": "India", "domains": ["manit.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.mnit.ac.in/"], "name": "Malaviya National Institute of Technology Jaipur", "country": "India", "domains": ["mnit.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tripurauniv.in/"], "name": "Tripura University", "country": "India", "domains": ["tripurauniv.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tshmc.org/"], "name": "Takhatmal Shrivallabh Homoeopathic Medical College", "country": "India", "domains": ["tshmc.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tumkuruniversity.ac.in/"], "name": "Tumkur University", "country": "India", "domains": ["tumkuruniversity.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.tvuni.in/"], "name": "Thiruvalluvar University", "country": "India", "domains": ["tvuni.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://uasbng.kar.nic.in/"], "name": "University of Agricultural Sciences, Bangalore", "country": "India", "domains": ["uasbng.kar.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.uasd.net/"], "name": "University of Agricultural Sciences, Dharwad", "country": "India", "domains": ["uasd.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.uktech.ac.in/"], "name": "Uttarakhand Technical University", "country": "India", "domains": ["uktech.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.uma.ac.in/"], "name": "University of Media Arts", "country": "India", "domains": ["uma.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://unical.ac.in/"], "name": "University of Calicut", "country": "India", "domains": ["unical.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.unigoa.ac.in/"], "name": "Goa University", "country": "India", "domains": ["unigoa.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.uni-mysore.ac.in/"], "name": "University of Mysore", "country": "India", "domains": ["uni-mysore.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.unipune.ernet.in/"], "name": "University of Pune", "country": "India", "domains": ["unipune.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.uniraj.org/"], "name": "University of Rajasthan", "country": "India", "domains": ["uniraj.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.unishivaji.ac.in/"], "name": "Shivaji University", "country": "India", "domains": ["unishivaji.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.unom.ac.in/"], "name": "University of Madras", "country": "India", "domains": ["unom.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.uohyd.ernet.in/"], "name": "University of Hyderabad", "country": "India", "domains": ["uohyd.ernet.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.uok.ac.in/"], "name": "University of Kota", "country": "India", "domains": ["uok.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.uor.org/"], "name": "University of Roorkee", "country": "India", "domains": ["uor.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.uou.ac.in/"], "name": "Uttarakhand Open University", "country": "India", "domains": ["uou.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.uptu.ac.in/"], "name": "Uttar Pradesh Technical University", "country": "India", "domains": ["uptu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.utkaluniv.org/"], "name": "Utkal University", "country": "India", "domains": ["utkaluniv.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://vbspu.ac.in/"], "name": "VBS Purvanchal University", "country": "India", "domains": ["vbspu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.vbu.co.in/"], "name": "Vinoba Bhave University", "country": "India", "domains": ["vbu.co.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.vidyasagar.ac.in/"], "name": "Vidyasagar University", "country": "India", "domains": ["vidyasagar.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.vignanuniversity.org/"], "name": "Vignan University", "country": "India", "domains": ["vignanuniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.vikramuniversity.org/"], "name": "Vikram University", "country": "India", "domains": ["vikramuniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.vinayakamissions.com/"], "name": "Vinayaka Mission's Research Foundation-Deemed University", "country": "India", "domains": ["vinayakamissions.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.visva-bharati.ac.in/"], "name": "Visva-Bharati University", "country": "India", "domains": ["visva-bharati.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.vit.ac.in/"], "name": "Vellore Institute of Technology", "country": "India", "domains": ["vit.ac.in"], "state-province": "Tamil Nadu"}, {"alpha_two_code": "IN", "web_pages": ["http://www.vksu-ara.org/"], "name": "Veer Kunwar Singh University", "country": "India", "domains": ["vksu-ara.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.vmou.ac.in/"], "name": "Vardhaman Mahaveer Open University", "country": "India", "domains": ["vmou.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.vnitnagpur.ac.in/"], "name": "Visvesvaraya National Institute of Technology", "country": "India", "domains": ["vnitnagpur.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.vssut.ac.in/"], "name": "Veer Surendra Sai University of Technology", "country": "India", "domains": ["vssut.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.vtu.ac.in/"], "name": "Visvesvaraya Technological University", "country": "India", "domains": ["vtu.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.wbuafs.nic.in/"], "name": "West Bengal University of Animal and Fishery Sciences", "country": "India", "domains": ["wbuafs.nic.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.wbut.net/"], "name": "West Bengal University of Technology", "country": "India", "domains": ["wbut.net"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ycmou.com/"], "name": "Yashawantrao Chavan Maharashtra Open University", "country": "India", "domains": ["ycmou.com"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["http://www.ysparmaruniversity.org/"], "name": "Dr. YS Parmar University of Horticulture and Forestry", "country": "India", "domains": ["ysparmaruniversity.org"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.charusat.ac.in/"], "name": "Charotar University of Science and Technology", "country": "India", "domains": ["charusat.ac.in"], "state-province": null}, {"alpha_two_code": "IN", "web_pages": ["https://www.nuv.ac.in/"], "name": "Navrachana University", "country": "India", "domains": ["nuv.ac.in"], "state-province": "Gujarat"}]
'''

# %%
ulist=ulist.replace('null','None')

# %%
mydict={"alpha_two_code": "IN", "web_pages": ["http://www.davietjal.org/"], "name": "DAV Institute of Engineering & Technology", "country": "India", "domains": ["davietjal.org"], "state-province": "Punjab"}

# %%
mydict
# Out:
# {'alpha_two_code': 'IN',
#  'country': 'India',
#  'domains': ['davietjal.org'],
#  'name': 'DAV Institute of Engineering & Technology',
#  'state-province': 'Punjab',
#  'web_pages': ['http://www.davietjal.org/']}

# %%
mydict.keys()
# Out:
# dict_keys(['alpha_two_code', 'web_pages', 'name', 'country', 'domains', 'state-province'])

# %%
mydict.values()
# Out:
# dict_values(['IN', ['http://www.davietjal.org/'], 'DAV Institute of Engineering & Technology', 'India', ['davietjal.org'], 'Punjab'])

# %%
mydict.items()
# Out:
# dict_items([('alpha_two_code', 'IN'), ('web_pages', ['http://www.davietjal.org/']), ('name', 'DAV Institute of Engineering & Technology'), ('country', 'India'), ('domains', ['davietjal.org']), ('state-province', 'Punjab')])

# %%
#fromkeys
l=['name','rollno','state']

# %%
s=dict.fromkeys(l)

# %%
s
# Out:
# {'name': None, 'rollno': None, 'state': None}

# %%
s['name']="Amit"

# %%
s
# Out:
# {'name': 'Amit', 'rollno': None, 'state': None}

# %%
s.update({'rollno':1001,'state':'Haryana'})

# %%
s
# Out:
# {'name': 'Amit', 'rollno': 1001, 'state': 'Haryana'}

# %%
s.update({'rollno':1001,'state':'Haryana','country':"IN"})

# %%
s
# Out:
# {'country': 'IN', 'name': 'Amit', 'rollno': 1001, 'state': 'Haryana'}

# %%
s.setdefault('pincode2','247001')
# Out:
# '247001'

# %%
s
# Out:
# {'country': 'IN',
#  'name': 'Amit',
#  'pincode': None,
#  'pincode2': '247001',
#  'rollno': 1001,
#  'state': 'Haryana'}

# %%
s.pop('pincode2')
# Out:
# '247001'

# %%
s
# Out:
# {'country': 'IN',
#  'name': 'Amit',
#  'pincode': None,
#  'rollno': 1001,
#  'state': 'Haryana'}

# %%
s.pop('pincode2')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-92-0f7d64389906> in <module>()
# ----> 1 s.pop('pincode2')
#
# KeyError: 'pincode2'

# %%
s.popitem()
# Out:
# ('pincode', None)

# %%
s
# Out:
# {'country': 'IN', 'name': 'Amit', 'rollno': 1001, 'state': 'Haryana'}

# %%
if 'rollno2' in s:
    print(s['rollno'])
